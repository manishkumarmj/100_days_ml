# %%
import numpy as np
import pandas as pd

# %%
spoti = pd.read_csv('A:\\spotify_churn_dataset.csv')

# %%
spoti.sample(10)
# Out:
#       user_id  gender  age country subscription_type  listening_time  \
# 4994     4995  Female   23      DE           Premium             230
# 7874     7875   Other   46      UK           Premium             296
# 5677     5678   Other   47      FR           Student              66
# 6746     6747    Male   53      DE           Student             232
# 2822     2823    Male   32      AU            Family             164
# 352       353   Other   41      CA            Family              78
# 1825     1826   Other   20      IN            Family             203
# 6125     6126  Female   18      UK           Student             263
# 7044     7045   Other   45      PK            Family             284
# 5369     5370   Other   20      IN           Student             111
#
#       songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 4994                    18       0.10         Web                      0
# ...

# %%
categories=[['Other','Male','Female'],
                 ['Family','Student','Free','Premium' ],
                   [ 'Mobile', 'Web','Desktop'], ]
