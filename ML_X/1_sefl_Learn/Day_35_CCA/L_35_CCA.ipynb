# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data_science_job.csv')

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# ...

# %%
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %% [markdown]
# # here we loose enough data
#  -> if we apply on below 5% of data
#  like city_development_index,enrolled_university

# %%
df.shape
# Out:
# (19158, 13)

# %% [markdown]
# # what we have done here
# we have extracted the columns of less than 5 %

# %%
cols = [var for var in df.columns if df[var].isnull().mean() < 0.05 and df[var].isnull().mean() > 0]
cols
# Out:
# ['city_development_index',
#  'enrolled_university',
#  'education_level',
#  'experience',
#  'training_hours']

# %%
df[cols].sample(5)
# Out:
#        city_development_index enrolled_university education_level  experience  \
# 16464                   0.920       no_enrollment        Graduate         4.0
# 4806                    0.624       no_enrollment        Graduate         0.0
# 4760                    0.698       no_enrollment     High School         0.0
# 11758                     NaN       no_enrollment         Masters        20.0
# 11800                   0.624       no_enrollment        Graduate         9.0
#
#        training_hours
# 16464            18.0
# 4806             20.0
# 4760              NaN
# 11758            36.0
# 11800            58.0

# %% [markdown]
# # ab yaha pe
# agar hamre pass 100 hote tho ab 89 row hoge hamre pass

# %%
len(df[cols].dropna())/len(df)
# Out:
# 0.8968577095730244

# %%
df['education_level'].value_counts()
# Out:
# education_level
# Graduate          11598
# Masters            4361
# High School        2017
# Phd                 414
# Primary School      308
# Name: count, dtype: int64

# %%
new_df = df[cols].dropna()
df.shape, new_df.shape
# Out:
# ((19158, 13), (17182, 5))

# %%
new_df.hist(bins=50, density=True, figsize=(12, 12))
plt.show()

# %% [markdown]
# *In below Grap you can se red and   Green both have alsmost same disturbiton at the same so changes are made*

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original data
df['training_hours'].hist(bins=50, ax=ax, density=True, color='red')

# data after cca, the argument alpha makes the color transparent, so we can
# see the overlay of the 2 distributions
new_df['training_hours'].hist(bins=50, ax=ax, color='green', density=True, alpha=0.8)
# Out:
# <Axes: >

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original data
df['training_hours'].plot.density(color='red',linewidth =3)

# data after cca
new_df['training_hours'].plot.density(color='green')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Removed missing data
# then plot with comparision of new and fresh data (after removeal )

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original data
df['city_development_index'].hist(bins=50, ax=ax, density=True, color='red')

# data after cca, the argument alpha makes the color transparent, so we can
# see the overlay of the 2 distributions
new_df['city_development_index'].hist(bins=50, ax=ax, color='green', density=True, alpha=0.8)
# Out:
# <Axes: >

# %% [markdown]
# # pdf of same data
#     * city_development_index

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original data
df['city_development_index'].plot.density(color='red')

# data after cca
new_df['city_development_index'].plot.density(color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original data
df['experience'].hist(bins=50, ax=ax, density=True, color='red')

# data after cca, the argument alpha makes the color transparent, so we can
# see the overlay of the 2 distributions
new_df['experience'].hist(bins=50, ax=ax, color='green', density=True, alpha=0.8)
# Out:
# <Axes: >

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original data
df['experience'].plot.density(color='red')

# data after cca
new_df['experience'].plot.density(color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
temp = pd.concat([
            # percentage of observations per category, original data
            df['enrolled_university'].value_counts() / len(df), # ratio nikal diya 

            # percentage of observations per category, cca data
            new_df['enrolled_university'].value_counts() / len(new_df) # ration nikal diya 
        ],
        axis=1)

# add column names
temp.columns = ['original', 'cca']

temp
# Out:
#                      original       cca
# enrolled_university
# no_enrollment        0.721213  0.735188
# Full time course     0.196106  0.200733
# Part time course     0.062533  0.064079

# %%
temp = pd.concat([
            # percentage of observations per category, original data
            df['education_level'].value_counts() / len(df),

            # percentage of observations per category, cca data
            new_df['education_level'].value_counts() / len(new_df)
        ],
        axis=1)

# add column names
temp.columns = ['original', 'cca']

temp
# Out:
#                  original       cca
# education_level
# Graduate         0.605387  0.619835
# Masters          0.227633  0.234082
# High School      0.105282  0.107380
# Phd              0.021610  0.022116
# Primary School   0.016077  0.016587
