# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tip= sns.load_dataset('tips')

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
titanic  =pd.read_csv('train.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 1. Scaterplot (Numberical vs Numberical )

# %%
sns.scatterplot(x=tip['total_bill'], y=tip['tip'],hue=tip['sex'],style=tip['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # 2. Bar plot (Numerical vs Categorical)

# %%
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 31            32         1       1
# 810          811         0       3
# 611          612         0       3
# 697          698         1       3
# 82            83         1       3
#
#                                                Name     Sex   Age  SibSp  \
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 810                          Alexander, Mr. William    male  26.0      0
# 611                           Jardin, Mr. Jose Neto    male   NaN      0
# 697                Mullens, Miss. Katherine "Katie"  female   NaN      0
# 82                   McDermott, Miss. Brigdet Delia  female   NaN      0
#
#      Parch              Ticket      Fare Cabin Embarked
# 31       0            PC 17569  146.5208   B78        C
# 810      0                3474    7.8875   NaN        S
# 611      0  SOTON/O.Q. 3101305    7.0500   NaN        S
# 697      0               35852    7.7333   NaN        Q
# ...

# %%
sns.barplot(x = titanic['Pclass'], y = titanic ['Age'],palette='Set1')
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_18676\2309266150.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = titanic['Pclass'], y = titanic ['Age'],palette='Set1')
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x = titanic['Pclass'], y = titanic ['Fare'],hue=titanic['Sex'],palette='Set1')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# # 3. Box plot (Numberical vs Categorical)

# %%
sns.boxplot(x = titanic['Sex'],y= titanic['Age'],palette='Set1',hue=titanic['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # Distplot (Numberical - Categorical )

# %%
# For newer seaborn versions
sns.histplot(titanic[titanic['Survived']==0]['Age'], label='Not Survived', kde=True, color='red', alpha=0.6)
sns.histplot(titanic[titanic['Survived']==1]['Age'], label='Survived', kde=True, color='green', alpha=0.6)
plt.legend()
plt.title('Age Distribution by Survival Status')
plt.show()

# %%
pd.crosstab(titanic['Pclass'],titanic['Sex'])
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
pd.crosstab(titanic['Pclass'],titanic['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pd.crosstab(titanic['Survived'],titanic['Sex'])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %% [markdown]
# * **sometime the grid become large so that we use heatmap instead of grid map**

# %%
sns.heatmap(pd.crosstab(titanic['Survived'],titanic['Sex']))
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic.groupby('Pclass').mean(numeric_only=True)['Survived']*100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
(titanic.groupby('Pclass').mean(numeric_only=True)['Survived']*100).plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %% [markdown]
# # 6. CLUSTER MAP (Categorical vs Categorical)

# %%
sns.clustermap(pd.crosstab(titanic['Parch'],titanic['Survived']))

# %% [markdown]
# # 7. Pairplot()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# # 8 Lineplot (numberical vs numerical  )

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.groupby('month').size().plot(kind="bar")
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_18676\433070215.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   flights.groupby('month').size().plot(kind="bar")
# <Axes: xlabel='month'>

# %%
new= flights.groupby('year').sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 new= flights.groupby('year').sum().reset_index()
#
# File c:\Users\manis\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:3146, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3141 else:
#    3142     # If we are grouping on categoricals we want unobserved categories to
#    3143     # return zero, rather than the default of NaN which the reindexing in
#    3144     # _agg_general() returns. GH #31422
#    3145     with com.temp_setattr(self, "observed", True):
# -> 3146         result = self._agg_general(
#    3147             numeric_only=numeric_only,
#    3148             min_count=min_count,
#    3149             alias="sum",
#    3150             npfunc=np.sum,
#    3151         )
#    3153     return self._reindex_output(result, fill_value=0)
#
# ...

# %%
flights.pivot_table(values='passengers', index = 'month', columns = 'year')
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_18676\354993013.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights.pivot_table(values='passengers', index = 'month', columns = 'year')
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# ...

# %%
sns.heatmap(flights.pivot_table(values='passengers', index = 'month', columns = 'year'))
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_18676\3033765196.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flights.pivot_table(values='passengers', index = 'month', columns = 'year'))
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(flights.pivot_table(values='passengers', index = 'month', columns = 'year'))
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_18676\944771525.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.clustermap(flights.pivot_table(values='passengers', index = 'month', columns = 'year'))
