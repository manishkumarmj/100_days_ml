# %%
class MeraLR:

    def __init__(self):
        self.m = None
        self.b = None
    def  fit(self, X_train, y_train):
        for i in range(X_train.shape[0]):# 160 time 
            num = 0 
            den = 0 
            

    def predict(self, X_test):
        pass

# %%
import numpy as np
import pandas as pd

# %%
df = pddf = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %% [markdown]
# # x and Y
#  * Whole row only cgpa column X
#  * Whole row only package  column Y

# %%
X = df.iloc[:,0].values # i want to extract the oth adress 
y= df.iloc[:,1].values # i want to extract the oth adress  from this dataframe .

# %%
from sklearn.model_selection import train_test_split

# %%
X_train ,X_test,y_train,y_test = train_test_split(X , y, test_size=0.2 , random_state=2)

# %%
X_train.shape
# Out:
# (160,)

# %%
lr = MeraLR()

# %%
lr.fit(X_train,y)
# Out:
# (160,)

# %% [markdown]
# # calculating m
#  * 1st calculate numerator
#  * 2nd calculate denominator
#  *  divide the numerator by denominaer .predict(X_test).shape

# %% [markdown]
# # numberator
# ![image.png](attachment:image.png)
