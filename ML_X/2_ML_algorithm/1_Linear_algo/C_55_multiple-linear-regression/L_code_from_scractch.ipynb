# %%
import numpy as np 
from sklearn.datasets import load_diabetes

# %% [markdown]
# # it basically convert it into numpy array

# %%
X,y =load_diabetes(return_X_y =True)

# %%
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
X.shape
# Out:
# (442, 10)

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
y.shape
# Out:
# (442,)

# %% [markdown]
# ## Using Sklearn's Linear Regression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y , test_size = 0.2,random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (353, 10)
# (89, 10)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %% [markdown]
# # Model trained
#  * sare coefficient a model train ho gya

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# predectited X_test value
# stored in Y_pred

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.4399338661568968

# %% [markdown]
#  * Here we have 10 input column
#  * so 10 beta value + 1 ( intercept value )

# %%
reg.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
reg.intercept_
# Out:
# np.float64(151.88331005254167)

# %% [markdown]
# ## Making our own Linear Regression Class
# * np.insert(X_train,0,1,axis=1 )# data, index , value , column (1) or row (0)
# * numpy.linalg.inv() this will help calcualte the inverse
# * np.linalg.inv(np.dot(X_train.T,X_train)) this will caluate the inverse
# * now then dot product
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # PREDECIT
# * X_test.dot coefficent wale matrix se
# * enke product ke baad jo product ayye ga unse Beta != add jar dena hai
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# here i can do the dot product of both
# X_test with coefficent
# ![image.png](attachment:image.png)

# %% [markdown]
# X_test = 89*10
# coeffiecetn  = 10,1

# %%
class MeraLr:
    # construtctor 
    def __inti__(self):
        self.coef = None # coefficient of the model train ho gya reg.fit(X,y)
        self.intercept_ = None
    def fit (self,X_train,y_train):
        print(X_train.shape)
        np.insert(X_train,0,1,axis=1 )# data, index , value , column (1) or row (0)
        
        # calcuate the coeffs (beta) 
        betas = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)# all beta values

        print(betas)
        self.intercept_ = betas[0] # sirf 0 item 
        self.coef_ = betas[1:] # sirf 1 item 


        #calculate the coefficient 
    def predict(self,X_test):
        y_pred = np.dot(X_test,self.coef_) + self.intercept_
        return y_pred

# %%
lr = MeraLr()

# %%
lr.fit(X_train, y_train)
# Out:
# (353, 10)
# [  11.10014699 -245.28091353  381.8791825   369.55714342 -918.39620672
#   601.65165138  131.74485109 -167.02405018 1055.08912682   54.60659094]

# %% [markdown]
# # Note that
#  * we have X_train and Y_train
#  * X_train don't have  1 addeded
#  * to resolve this we would add 1
#  * by using np.inster

# %%
np.insert(X_train,0,1,axis=1).shape
# Out:
# (353, 11)

# %%
y_pred = lr.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 y_pred = lr.predict(X_test)
#
# Cell In[44], line 20, in MeraLr.predict(self, X_test)
#      19 def predict(self,X_test):
# ---> 20     y_pred = np.dot(X_test,self.coef_) + self.intercept_
#      21     return y_pred
#
# ValueError: shapes (89,10) and (9,) not aligned: 10 (dim 1) != 9 (dim 0)
