# %%
list1 = ["M", "na", "i", "Kh"]
list2 = ["y", "me", "s", "an"]
L3 = [[]]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 L3.ndim
#
# AttributeError: 'list' object has no attribute 'ndim'
