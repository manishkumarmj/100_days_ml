# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('startup_funding.csv')
df.sample(10)
# Out:
#       Sr No Date dd/mm/yyyy Startup Name  \
# 1710   1711      18/05/2016    TheSmartQ
# 609     610      19/09/2017  High Radius
# 2683   2684      03/06/2015     MyPoolin
# 1455   1456      17/08/2016       Pikkol
# 2761   2762      05/05/2015  Customer360
# 1200   1201      05/11/2016       Medzin
# 671     672      28/08/2017      Mobikon
# 2528   2529      17/08/2015         Fixy
# 1826   1827      03/03/2016     Vertuals
# 1201   1202      05/11/2016      Bizongo
#
#                          Industry Vertical  \
# 1710                     Consumer Internet
# 609                             Technology
# 2683                 P2P Payments platform
# 1455                             Logistics
# 2761          Customer Engagement Platform
# 1200                             eCommerce
# 671                             Technology
# 2528  On demand cleaning & fixing services
# 1826                            Technology
# 1201                             eCommerce
#
#                                            SubVertical City  Location  \
# 1710                          Food Ordering Mobile App      Bangalore
# 609          Integrated receivables software solutions      Hyderabad
# 2683                                               NaN      New Delhi
# 1455                                  Packers & Movers      Bangalore
# 2761                                               NaN         Mumbai
# 1200           Online ordering & Delivery of medicines      New Delhi
# 671                    Restaurant & Hotel CRM platform           Pune
# 2528                                               NaN         Mumbai
# 1826  Audio Visual Digital Content creators for Brands         Mumbai
# 1201                    Packaging Material Marketplace         Mumbai
#
#                                          Investors Name InvestmentnType  \
# 1710                                YourNest Angel Fund    Seed Funding
# 609                       Susquehanna Growth Equity LLC  Private Equity
# 2683  Sharad Sharma, Rajan Anandan, Sunil Kalra, Ami...    Seed Funding
# 1455                               Indian Angel Network    Seed Funding
# 2761                                      Vishwas Patel    Seed Funding
# 1200                                       A M Sikander    Seed Funding
# 671           Sistema Asia Fund, C31 Ventures, Qualgro.  Private Equity
# 2528                                     VentureNursery    Seed Funding
# 1826                                         Dino Morea    Seed Funding
# 1201                       IDG Ventures, Accel Partners  Private Equity
#
#      Amount in USD Remarks
# 1710      2,50,000     NaN
# 609    5,00,00,000     NaN
# 2683           NaN     NaN
# 1455           NaN     NaN
# 2761           NaN     NaN
# 1200        45,000     NaN
# 671      70,00,000     NaN
# 2528           NaN     NaN
# 1826           NaN     NaN
# 1201     30,00,000     NaN

# %%
df['Investors Name'].isna().sum()
# Out:
# np.int64(24)

# %%
df['Investors Name']=df['Investors Name'].fillna('Undisclosed')

# %%
sorted(df['Startup Name'].unique().tolist())
# Out:
# ['"BYJU\\\\\'S"',
#  '#Fame',
#  '121Policy',
#  '19th mile',
#  '1Crowd',
#  '1mg',
#  '1mg (Healthkartplus)',
#  '20Dresses',
#  '33Coupons',
#  '360Ride',
#  '3Dexter',
#  '3HCare',
#  '3rdFlix',
#  '48East',
#  '4tigo',
#  '5th Vital',
#  '6Degree',
#  '75F',
#  '91SpringBoard',
#  '99Games',
#  '99PerHour',
#  '9Stacks',
#  'A&R Bon Vivants',
#  'ABI Health',
#  'AEON Learning',
#  'AHA Taxis',
#  'AYE Finance',
#  'AadharAPI.com',
#  'Aadyah',
#  'Aahaa',
#  'Aahaa Stores',
#  'Aarav UAV',
#  'Aasaanjobs',
#  'Aashiyaan',
#  'Aavishkaar-Intellecap Group',
#  'AbeRuk',
#  'Abhibus',
#  'Absentia',
#  'Absentia VR',
#  'Ace Turtle',
#  'Ace2three',
#  'Acko',
#  'ActOnMagic',
#  'Actionable Analytics',
#  'Active AI',
#  'Active.ai',
#  'Actofit',
#  'Ad2pro',
#  'AdPushUp',
#  'AdStringO',
#  'AdUrCup',
#  'AdWyze',
#  'Address Health',
#  'AdmitKard',
#  'Advanced Structures India',
#  'Advantage Club',
#  'Advenio',
#  'Adytude',
#  'Aequm',
#  'AerMed',
#  'Affimity',
#  'Affordplan',
#  'Agara Labs',
#  'AgentDesks',
#  'Agricxlab',
#  'Agrostar',
#  'Agrowave',
#  'AirCTO',
#  'AirMed Labs',
#  'AirZaar',
#  'Airpay',
#  'Airwood',
#  'Aisle',
#  'Aisle.co',
#  'Akosha',
#  'Alef\\\\nMobitech',
#  'AllIzHealth',
#  'Allygrow Technologies',
#  'AlmaConnect',
#  'AlmaMapper',
#  'Alpha Capital',
#  'Alteria Capital',
#  'Alternacare',
#  'Altizone',
#  'Amagi Media Labs',
#  'Ambee',
#  'American Vision',
#  'Amigobulls',
#  'Ampere',
#  'Ampere Vehicles',
#  'Anakage',
#  'Anandakanda',
#  'Anchanto',
#  'Annapurna Finance',
#  'Antuit',
#  'AppBrowzer',
#  'AppDaily',
#  'AppLop',
#  'AppVirality',
#  'Appario Retail Pvt Ltd.',
#  'Appbase',
#  'Appedo',
#  'Appie',
#  'AppilyEver',
#  'Appknox',
#  'Applicate',
#  'Applied Solar Technologies',
#  'Applop',
#  'AppsDaily',
#  'Appsdaily',
#  'Appvigil',
#  'Arcatron',
#  'Arcatron Mobility',
#  'Ark Robot',
#  'Arkin Net',
#  'Arohan Financial Services',
#  'Arth DesignBuild',
#  'Artoo',
#  'Arya.ai',
#  'Aryaka',
#  'Asia Institute Of Medical Science',
#  'AskMyGift',
#  'Asocon',
#  'Ather Energy',
#  'Athletto',
#  'Atlan',
#  'Atomberg',
#  'Atomberg Technology',
#  'Attune Technologies',
#  'Augrav',
#  'AutoGrid',
#  'AutoSense',
#  'Autobix',
#  'Automation Anywhere',
#  'Autorox.co',
#  'Avagmah',
#  'Avail Finance',
#  'AvailFinance',
#  'Avanti Learning',
#  'Avenue Growth',
#  'Avishkaar Box',
#  'Awaaz De',
#  'Awesummly',
#  'Awfis',
#  'Awign',
#  'Axio',
#  'Axtria',
#  'Aye Finance',
#  'AyeFinance',
#  'Azah',
#  'Azuro',
#  'B9 Beverages',
#  'BHIVE',
#  'BHIVE Workspace',
#  'BRIDGEi2I',
#  'BYG',
#  'BYJU\\\\xe2\\\\x80\\\\x99s',
#  'BYJU’S',
#  'Babajobs',
#  'Baby Berry',
#  'BabyChakra',
#  'Babychakra',
#  'Babygogo',
#  'BabyonBoard',
#  'Badiyajobs',
#  'BaggOut',
#  'Balance App',
#  'Banihal',
#  'Bank Bazaar',
#  'BankBazaar',
#  'BankerBay',
#  'Bats on delivery',
#  'Baxi',
#  'Be U Salons',
#  'BeaconsTalk',
#  'Beardo',
#  'BeatRoute',
#  'BedBathMore',
#  'Belita',
#  'Belong',
#  'Benepik',
#  'Bestdealfinance',
#  'BetaOut',
#  'Betaout',
#  'Better Mortgage',
#  'BetterButter.in',
#  'BetterPlace',
#  'Betterplace',
#  'Bevy',
#  'Bewakoof',
#  'Beyond Evolution',
#  'Bharat Bazaar',
#  'BharatPe',
#  'BhiveWorkspace',
#  'BiBox',
#  'Bidgely',
#  'Big Basket',
#  'Big Fish Ventures',
#  'BigBasket',
#  'BigStylist',
#  'BigStylist.com',
#  'Bikxie',
#  'BillDesk',
#  'Billion Loans',
#  'Bira91',
#  'Biryani Blues',
#  'Biryani By Kilo',
#  'BitGiving',
#  'Bite Club',
#  'Biteclub',
#  'Bitla Software',
#  'Biz2Credit',
#  'Bizom',
#  'Bizongo',
#  'Black Soil',
#  'Black White Orange',
#  'Black White Orange Brands',
#  'BlackBuck',
#  'Blackbuck',
#  'Blinge',
#  'BlogBeats',
#  'Blood n Care',
#  'Blowhorn',
#  'Blubox',
#  'Blue Box Media',
#  'Blue Tokai Coffee',
#  'BlueStone',
#  'Bluebirch',
#  'Bluegape',
#  'Bluegape.com',
#  'Board Infinity',
#  'Bobble',
#  'BoiBanit',
#  'BolRealty',
#  'Bollant Industries',
#  'Bolo App',
#  'Bombay Shaving Company',
#  'Bombay Shirt Company',
#  'Bona Vita',
#  'Bonhomia',
#  'Bonphulapl',
#  'Book My Diamond',
#  'Book My Show',
#  'Book Servicing',
#  'BookEventz',
#  'BookMeIn',
#  'BookMyBai',
#  'BookMyShow',
#  'Bottr.me',
#  'Bounty App',
#  'Box My Space',
#  'Box8',
#  'Boxmyspace',
#  'Boxx.ai',
#  'Brick2Wall',
#  'Brigge',
#  'Briston Technomach',
#  'Bro4U',
#  'BroEx',
#  'Broomberg',
#  'Browntape',
#  'BrowserStack',
#  'Bucker',
#  'Buddy',
#  'Buddy4studdy',
#  'Bueno',
#  'BuildSupply',
#  'BuildTraders',
#  'Buildkar',
#  'Buildzar',
#  'Bumper',
#  'Burger Singh',
#  'Buttercups',
#  'Butterfly Interactive',
#  'BuyHatke',
#  'Byju\\\\xe2\\\\x80\\\\x99s',
#  'CAKART.in',
#  'CBREX',
#  'CBS',
#  'CCAvenue',
#  'CCavenue',
#  'CREO',
#  'CRON Systems',
#  'CaRPM',
#  'Cabsguru',
#  'Call Health',
#  'Campus Diaries',
#  'CanvasFlip',
#  'Canvera',
#  'Canvs',
#  'Capabiliti',
#  'Capillary',
#  'Capillary Tech',
#  'Capita World',
#  'Capital Float',
#  'Capricoast',
#  'Capzest',
#  'CarDekho',
#  'CarDekho.com',
#  'CarTrade',
#  'CarTrade.com',
#  'Caratlane.com',
#  'Caravan Craft',
#  'Caravan Craft Retail',
#  'Carcrew.in',
#  'Care24',
#  'Career Anna',
#  'Career360',
#  'CareonGO',
#  'Careongo',
#  'Carl\\\\xe2\\\\x80\\\\x99s Jr',
#  'Cars24',
#  'Cartisan',
#  'Cartrade',
#  'CarveNiche',
#  'Casa2inns',
#  'Cash Suvidha',
#  'CashFree',
#  'Cashe',
#  'Cashflo',
#  'Cashify',
#  'Cashkaro',
#  'Cashkaro.com',
#  'Cashkumar',
#  'Celerix',
#  'Celes Care',
#  'Cerebroz',
#  'Chaayos',
#  'Chai Point',
#  'Chai Thela',
#  'ChaiPoint',
#  'Chakr Innovation',
#  'Changer Mints',
#  'ChargeBee',
#  'Chargebee',
#  'Chargein',
#  'ChatOnGo',
#  'CheersOye!',
#  'Chefs Basket',
#  'Chevon',
#  'Chikoop',
#  'Chillr',
#  'ChipperSage',
#  'Chloroplast Foods',
#  'ChqBook',
#  'Chrysalis',
#  'Chumbak',
#  'Chymera VR',
#  'CimplyFive',
#  'Citrus Payment',
#  'CityFlo',
#  'CityFurnish',
#  'CityShor',
#  'Civilsdaily',
#  'Clapsnslaps',
#  'CleanseCar',
#  'ClearTax',
#  'Cleartax',
#  'Cleartrip',
#  'CleverSharks',
#  'CleverTap',
#  'Click2Clinic',
#  'Clip App',
#  'Clodura',
#  'Clonect Solutions',
#  'Cloud Lending',
#  'Cloudacar',
#  'Cloudcherry Analytics',
#  'Cloudrino',
#  'Clovia',
#  'Clumio',
#  'Co Life',
#  'Codemojo',
#  'CodingLabs',
#  'CoinTribe',
#  'CollPoll',
#  'CollateBox',
#  'Collateral Medical',
#  'Collectabillia',
#  'CollegeDekho',
#  'CollegeDunia',
#  'Comarete',
#  'Commeasure',
#  'Commonfloor',
#  'Commut',
#  'ConfirmTKT',
#  'ConfirmtTkt',
#  'Connaizen',
#  'Connect India',
#  'ConnectAbank',
#  'Consure Medical',
#  'Convegenius',
#  'Cooey',
#  'Cookaroo',
#  'Cookifi',
#  'Coolshare',
#  'Coppre',
#  'Corporate360',
#  'Corseco',
#  'CouponRaja',
#  'CoutLoot',
#  'Coutloot',
#  'CoveIoT',
#  'CoverFox',
#  'Coverfox',
#  'CraftsVilla',
#  'Craftstvilla',
#  'Craftsvilla',
#  'Crayon Data',
#  'Creator\\\\xe2\\\\x80\\\\x99s Gurukul',
#  'CredR',
#  'CrediHealth',
#  'Credifiable',
#  'Credihealth',
#  'Credit Mate',
#  'Credit Sudhaar',
#  'Credit Vidya',
#  'CreditMantri',
#  'CreditMate',
#  'CreditSeva',
#  'CreditVidya',
#  'Credright',
#  'Credy',
#  'CroFarm',
#  'Crofarm',
#  'CropIn',
#  'Cropin',
#  'Crossahead',
#  'Crowdera',
#  'Crowdfire (formerly Justunfollow)',
#  'Crown-it',
#  'CrownIt',
#  'Crownit',
#  'Cube Consumer Services',
#  'Cube26',
#  'Cuberoot',
#  'Cubito',
#  'CueMath',
#  'Cuelearn',
#  'Cult',
#  'Cult Fitness',
#  'Culture Machine',
#  'CultureAlley',
#  'Cupick',
#  'CupoNation',
#  'Curatio',
#  'Cure Fit',
#  'CureFit',
#  'CureInstant',
#  'CureJoy',
#  'Curefit',
#  'Curie Labs',
#  'Curiositi',
#  'Curofy',
#  'CustomFurnish.com',
#  'Customer360',
#  'CustomerSucessBox',
#  'Customfurnish',
#  'Cyclops',
#  'CyclopsMedtech',
#  'Cygnus Hospitals',
#  'DAAKI',
#  'Daalchini Technologies',
#  'Daily Ninja',
#  'Daily Rounds',
#  'Daily hunt',
#  'DailyHunt',
#  'DailyNinja',
#  'DailyObjects',
#  'DailyRounds',
#  'DarwinBox',
#  'Data Resolve',
#  'DataWeave',
#  'DawaiLelo',
#  'DayBox',
#  'Dazo',
#  'Deal 4Loans',
#  'Deal Street Asia',
#  'Deal4Loans / Wishfin',
#  'Dealwithus',
#  'Dekkho',
#  'Delhivery',
#  'Delight Foods',
#  'Demyto',
#  'Derbii',
#  'Design Cafe',
#  'DesignBids',
#  'Devourin',
#  'Deyor Camps',
#  'Deyor Rooms',
#  'Dhruva',
#  'Dhruva Space',
#  'DiabetOmics',
#  'Didi',
#  'Digiconectt',
#  'Digilend',
#  'Digio',
#  'Digit',
#  'Digital F5',
#  'Digital Gorkha',
#  'Digital Mall Asia',
#  'Dil Mil',
#  'Dipper',
#  'Direct Create',
#  'Diro Labs',
#  'DishCo',
#  'Disprz',
#  'Djubo.com',
#  'DoSelect',
#  'DocPlexus',
#  'DocTalk',
#  'DocsApp',
#  'Doctor Insta',
#  'DoctorInsta',
#  'DogSpot',
#  'Don\\\\xe2\\\\x80\\\\x99t Scratch Your Head',
#  'DoneThing',
#  'DoodhWala',
#  'Doormint',
#  'Doxper',
#  'Dream Wallets',
#  'Dream11',
#  'Drip capital',
#  'DriveSkool',
#  'DriveU',
#  'DriversCart',
#  'Drivestream',
#  'Drivezy',
#  'Drivify',
#  'DrivoJoy',
#  'Droom',
#  'Droom.in',
#  'DropKaffe',
#  'Dropkaffe',
#  'Drums Food',
#  'Druva',
#  'Duffl',
#  'Dunzo',
#  'EPS',
#  'EPayLater',
#  'ERA',
#  'Early Salary',
#  'EarlySalary',
#  'EarlySalary.com',
#  'Earth Food',
#  'Easy Diner',
#  'EasyEcom',
#  'EasyFix',
#  'EasyGov',
#  'EasyKhaana',
#  'EasyPolicy',
#  'EasyRewardz',
#  'EasyRoads',
#  'Easypolicy',
#  'Eat.Shop.Love',
#  'Eatfresh',
#  'Eatlo',
#  'Eatonomist',
#  'Eattreatonline',
#  'Eazy Coach',
#  'EazyDiner',
#  'Eckovation',
#  'Ecolibriumenergy',
#  'Ecom Express',
#  'Ecozen',
#  'EdTechReview',
#  'Edelweiss',
#  'EdgeFx',
#  'Edu4Share',
#  'EduAce Services',
#  'EduBridge',
#  'EduKart',
#  'EduPristine',
#  'EduRev',
#  'Edureka',
#  'Edurev',
#  'Edyoo',
#  'Elanic',
#  'ElastiRun',
#  'ElasticRun',
#  'ElderAid Wellness',
#  'Elemential',
#  'Elucidata',
#  'Emflux Motors',
#  'Emiza',
#  'Emojifi',
#  'Enabli',
#  'Enakshi',
#  'Endless Robotics',
#  'Engineer.ai',
#  'EngineerBabu',
#  'Englishleap.com',
#  'Entropik',
#  'Entropika',
#  'Entropy Innovations',
#  'Envoged',
#  'Epiq Capital',
#  'Eruditus',
#  'Ethinos',
#  'Ethosh',
#  'EureQa',
#  'EvenGini',
#  'EveningFlavors',
#  'Events High',
#  'Explara',
#  'Explore Life traveling',
#  'ExtraCarbon',
#  'ExtraaEdge',
#  'Eywa Media',
#  'EzCred',
#  'Ezetap',
#  'EzySolare',
#  'Ezyhaul',
#  'Ezytruk',
#  'FPL Technologies',
#  'FR8',
#  'FTCash',
#  'FXMartIndia',
#  'FYNE',
#  'FYRE',
#  'Faaso\\\\xe2\\\\x80\\\\x99s',
#  'Faasos',
#  'Faaya',
#  'Fab Hotels',
#  'FabAlley',
#  'FabHotels',
#  'FabX',
#  'FableStreet',
#  'Fabogo',
#  'Fabulyst',
#  'Faircent',
#  'Faircent.com',
#  'FalconBrick',
#  'FarEye',
#  'FarMart',
#  'Farm Taaza',
#  'FarmLink',
#  'Farmizen',
#  'Fashalot',
#  'Fashionablyin',
#  'Fashionove',
#  'Fashor',
#  'FastFox',
#  'Fastudent',
#  'FeetApart',
#  'FiTraQ',
#  'Fieldassist',
#  'Finance Buddha',
#  'Fincash',
#  'Find My Stay',
#  'FindUrClass',
#  'FindYahan',
#  'FindmeaShoe',
#  'Findow',
#  'Findyahan',
#  'Fingerlix',
#  'Finomena',
#  'Finova Capital',
#  'Fintellix',
#  'Fintobox',
#  'Finzy',
#  'First Eat',
#  'First Moms Club',
#  'FirstCry',
#  'FirstCry.com',
#  'FirstTouch',
#  'Fisdom',
#  'FitMeIn',
#  'Fitcircle',
#  'Fitmein',
#  'Fitnapp',
#  'Fitpass',
#  'Fitraq.com',
#  'Fitso',
#  'Fitternity',
#  'Five Star Group',
#  'FixNix',
#  'Fixy',
#  'Flashdoor',
#  'FlatFurnish',
#  'Flatchat',
#  'Flatpebble',
#  'FleetRover',
#  'FleetX',
#  'Flexiloans',
#  'Flexing It',
#  'FlickBay',
#  'Flickstree',
#  'FlipClass',
#  'Flipkart',
#  'Flipkart.com',
#  'Flixy Games',
#  'Flocareer',
#  'Flochat',
#  'Flutura',
#  'Flyrobe',
#  'Flytxt',
#  'Focus Digit',
#  'FoodAbhi',
#  'FoodTalkIndia',
#  'Foodmemories',
#  'Foodpanda',
#  'ForeverShop',
#  'Formcept',
#  'Fourseven',
#  'Fourth Ambit',
#  'Fourth Partner Energy',
#  'Foyr.com',
#  'Fracktal Works',
#  'Fractal Analytics',
#  'Frankly',
#  'Frapperz',
#  'FreeCharge',
#  'Freedom Smart Labs',
#  'Fresh Food Concepts',
#  'FreshBoxx',
#  'FreshDesk',
#  'FreshMenu',
#  'FreshVnF',
#  'FreshWorld',
#  'Freshboxx',
#  'Freshdesk',
#  'Freshee',
#  'Freshmonk',
#  'Freshworks',
#  'Front Desk AI',
#  'FroyoFit',
#  'Frsh',
#  'Frsh.co.in',
#  'Ftcash',
#  'Fulfil.IO',
#  'FunOnGo',
#  'Funcart',
#  'Funcastic',
#  'Fundamentor',
#  'FundsIndia.com',
#  'Furdo',
#  'Furlenco',
#  'Furtados School of Music',
#  'Fusion Microfinance',
#  'Fxkart.com',
#  'Fyle',
#  'Fyle Technologies',
#  'Fynd',
#  'GIBBS',
#  'GIBSS',
#  'GOQii',
#  'Gaana',
#  'Gaana.com',
#  'Gadgets 360',
#  'Gadgetwood',
#  'Gajty',
#  'Galleri5',
#  'GameXS.in',
#  'GameZop',
#  'Gameezop',
#  'Gaming Monk',
#  'Gamooz',
#  'Gapoon',
#  'Garage On Road',
#  'GenNext Students',
#  'Genextstudents',
#  'Genie',
#  'Genius Corner',
#  'Get My Parking',
#  'Get Simpl',
#  'GetFocus',
#  'GetMyPeon',
#  'GetVee',
#  'Giftxoxo',
#  'GigIndia',
#  'Gingercrush',
#  'Girnar Software',
#  'Glam Studios',
#  'GlamStudios',
#  'Glamrs',
#  'Glassic',
#  'GlowRoad',
#  'Glowroad',
#  'Glowship',
#  'GoBumpr',
#  'GoChoppers',
#  'GoComet',
#  'GoDesi',
#  'GoFro',
#  'GoFynd',
#  'GoGo Truck',
#  'GoJavas',
#  'GoMechanic',
#  'GoPigeon',
#  'GoQii',
#  'GoYaNo',
#  'GoZefo',
#  'Goalwise',
#  'Gobolt',
#  'Godof Hospitals',
#  'GoldFarm',
#  'GolfLAN',
#  'Gomalon',
#  'Good Methods Global',
#  'Goodbox',
#  'Goodera',
#  'Goodservice',
#  'Goomo',
#  'Goqii',
#  'Gozoomo',
#  'Grab',
#  'Grab.in',
#  'GrabOnRent',
#  'Grabhouse',
#  'Grabhouse.com',
#  'Gradopedia',
#  'GramCover',
#  'Gramophone',
#  'GrandOpinion',
#  'Graphene',
#  'Graphic India',
#  'Gray Routes',
#  'Greenlight Planet',
#  'Grex',
#  'Grey Campus',
#  'Grey Orange',
#  'GreyAtom',
#  'GreytHR',
#  'Gridle',
#  'Grofers',
#  'Groupon India',
#  'Grover Zampa',
#  'Grow Fit',
#  'GrowFitter',
#  'Groww',
#  'Guarented',
#  'Guiddoo',
#  'Guidoo',
#  'GuruG Learning',
#  'Gurukul',
#  'Gyaanzone',
#  'GyanDhan',
#  'GymTrekker',
#  'Gympik',
#  'Gympik.com',
#  'HEAL Institute',
#  'HUG Innovations',
#  'HWell24',
#  'HWell24 Plus',
#  'HackerEarth',
#  'HackerRank',
#  'HalaPlay',
#  'HandyHome',
#  'HandyTrain',
#  'Hansa Customer Equity',
#  'Hansel io',
#  'Hansel.io',
#  'Happily Unmarried',
#  'HappilyUnmarried',
#  'Happitoo',
#  'Happy EMI',
#  'Happy2Refer',
#  'HappyGoEasy',
#  'Happydemic',
#  'Haptik',
#  'Haqdarshak',
#  'Harness Handitouch',
#  'HashLearn',
#  'HashTaag',
#  'Hasura',
#  'HeadOut',
#  'Heads Up For Tails',
#  'Healers At Home',
#  'HealthAssure',
#  'HealthCare',
#  'HealthEminds',
#  'HealthEnablr',
#  'HealthFin',
#  'HealthIntel',
#  'HealthKart',
#  'HealthKumbh',
#  'HealthMir',
#  'HealthSutra',
#  'Healthbuds',
#  'Healthcare at Home',
#  'Healthi',
#  'Healthians',
#  'Healthians.com',
#  'HealthifyMe',
#  'Healthifyme',
#  'Healthsignz',
#  'HealthyWorld.in',
#  'Heckyl',
#  'Hello Curry',
#  'Hello Tax',
#  'HelpChat',
#  'HelpShift',
#  'Helpi',
#  'Heterogenous',
#  'Hevo Data',
#  'HeyBiz',
#  'HeyPillow',
#  'HiJinny',
#  'High Radius',
#  'HighRadius',
#  'Highway Delite',
#  'Hike',
#  'Hike Messenger',
#  'HipBar',
#  'HipCouch',
#  'Hipcask',
#  'Hippily',
#  'Hipship',
#  'HitGrit',
#  'Hitwicket',
#  'HolaChef',
#  'Holachef',
#  'HolidayIQ',
#  'Holidify',
#  'Holisol Logistics',
#  'HomeCapital',
#  'HomeLane',
#  'HomeStudio',
#  'Homelane',
#  'Homergize',
#  'Homers.in',
#  'Hoopy',
#  'Hopping Chef',
#  'Hoppingo',
#  'Hopscotch',
#  'Horntell',
#  'Hostel Dunia',
#  'Hotelogix',
#  'Hotify',
#  'House of Msasaba',
#  'Housejoy',
#  'Housing',
#  'Housing.com',
#  'HousingMan',
#  'Houssup',
#  'Howdy Ventures',
#  'Hubilo',
#  'Hugefly',
#  'Hungama',
#  'HungerBox',
#  'Hungry Foal',
#  'HyperTrack',
#  'HyperVerge',
#  'Hypernova Interactive',
#  'I Can Stay',
#  'IBSFintech',
#  'ICHR',
#  'ICustomMadeIt',
#  'IDG Ventures',
#  'IDfy',
#  'IFMR Holdings',
#  'IGP.com',
#  'IIM Jobs',
#  'IMAX Program',
#  'IMbesharam',
#  'INDwealth',
#  'ION Energy',
#  'IOTrek',
#  'IQlect',
#  'ISFC',
#  'Icertis',
#  'Idea Bubbles',
#  'IdeaChakki',
#  'IdeaForge',
#  'Ideal Insurance',
#  'Ignis Careers',
#  'ImageProVision',
#  'Imaginate',
#  'Imarticus Learning',
#  'Impact Analytics',
#  'Impact Guru',
#  'ImpactGuru',
#  'Impartus',
#  'InCred',
#  'InCred Finance',
#  'Inayo',
#  'Inc42',
#  'Inclov',
#  'Increff',
#  'Indee',
#  'Indi.com',
#  'India Gifts Portal',
#  'India Lends',
#  'IndiaLends',
#  'Indiamart',
#  'IndianRoots.com',
#  'Indiez',
#  'Indifi',
#  'IndigoLearn',
#  'Indix',
#  'Indofash',
#  'Indus OS',
#  'IndustryBuying',
#  'Industrybuying',
#  'Infibeam',
#  'Infinite Analytics',
#  'Infisecure',
#  'Infogain',
#  'Infoworks',
#  ...]
