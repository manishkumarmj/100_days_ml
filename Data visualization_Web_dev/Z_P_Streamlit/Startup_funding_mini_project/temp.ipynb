# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('startup_funding.csv')
df.sample(10)
# Out:
#       Sr No        Date         Startup Name  \
# 864     865  2017-04-04          Konsult App
# 387     388  2018-02-27               Trilyo
# 969     970  2017-03-22         The Mons Co.
# 1480   1481  2016-08-25              NearFox
# 1291   1292  2016-10-13          Shoekonnect
# 1800   1801  2016-04-22              Licious
# 671     672  2017-08-28              Mobikon
# 2603   2604  2015-07-09  \\xc2\\xa0Bluestone
# 1441   1442  2016-08-12           Innovaccer
# 2170   2171  2015-12-18      Ampere Vehicles
#
#                      Industry Vertical  \
# 864                  Consumer Internet
# 387                         Technology
# 969                          eCommerce
# 1480                 Consumer Internet
# 1291                         eCommerce
# 1800                         eCommerce
# 671                         Technology
# 2603  \\xc2\\xa0Online Jewellery Store
# 1441                        Technology
# 2170       Electric Bike Manufacturers
#
# ...

# %%
df['Investors Name'].isna().sum()
# Out:
# np.int64(24)

# %%
df['Investors Name']=df['Investors Name'].fillna('Undisclosed')

# %%
sorted(df['Startup Name'].unique().tolist())
# Out:
# ['"BYJU\\\\\'S"',
#  '#Fame',
#  '121Policy',
#  '19th mile',
#  '1Crowd',
#  '1mg',
#  '1mg (Healthkartplus)',
#  '20Dresses',
#  '33Coupons',
#  '360Ride',
#  '3Dexter',
#  '3HCare',
#  '3rdFlix',
#  '48East',
#  '4tigo',
#  '5th Vital',
#  '6Degree',
#  '75F',
#  '91SpringBoard',
#  '99Games',
#  '99PerHour',
#  '9Stacks',
#  'A&R Bon Vivants',
#  'ABI Health',
#  'AEON Learning',
#  'AHA Taxis',
#  'AYE Finance',
#  'AadharAPI.com',
#  'Aadyah',
#  'Aahaa',
#  'Aahaa Stores',
#  'Aarav UAV',
#  'Aasaanjobs',
#  'Aashiyaan',
#  'Aavishkaar-Intellecap Group',
#  'AbeRuk',
#  'Abhibus',
#  'Absentia',
#  'Absentia VR',
#  'Ace Turtle',
#  'Ace2three',
#  'Acko',
#  'ActOnMagic',
#  'Actionable Analytics',
#  'Active AI',
#  'Active.ai',
#  'Actofit',
#  'Ad2pro',
#  'AdPushUp',
#  'AdStringO',
#  'AdUrCup',
#  'AdWyze',
#  'Address Health',
#  'AdmitKard',
#  'Advanced Structures India',
#  'Advantage Club',
#  'Advenio',
#  'Adytude',
#  'Aequm',
#  'AerMed',
#  'Affimity',
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date               3044 non-null   str
#  2   Startup Name       3044 non-null   str
#  3   Industry Vertical  2873 non-null   str
#  4   SubVertical        2108 non-null   str
#  5   City  Location     2864 non-null   str
#  6   Investors Name     3044 non-null   str
#  7   InvestmentnType    3040 non-null   str
#  8   Amount in USD      2084 non-null   str
#  9   Remarks            419 non-null    str
# dtypes: int64(1), str(9)
# memory usage: 593.2 KB

# %%
df.set_index("Sr No", inplace = True)

# %%
df.rename(columns={
    "Date":"date",
    "Startup Name":"starup",
    "Industry Vertical":"Vertical",
    "SubVertical":"subvertical",
    "City  Location":"city",
    "Investors Name":"investors",
    "InvestmentnType":"Round",
    "Amount in USD": "amount",

},inplace=True)

# %%
df.head()
# Out:
#              date                        starup             Vertical  \
# Sr No
# 1      2020-01-09                        BYJU’S               E-Tech
# 2      2020-01-13                        Shuttl       Transportation
# 3      2020-01-09                     Mamaearth           E-commerce
# 4      2020-01-02  https://www.wealthbucket.in/              FinTech
# 5      2020-01-02                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 Round        amount Remarks
# Sr No
# 1        Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %% [markdown]
# # Convert  String amount --> int :

# %%
df["amount"]=df["amount"].fillna('0') # undisclosed amount filled 
df["amount"]=df["amount"].str.replace(",","")
df["amount"]=df["amount"].str.replace("undisclosed","0")
df["amount"]=df["amount"].str.replace("Undisclosed","0")

# %%
df = df[df["amount"].str.isdigit()]

# %%
df["amount"] =df["amount"].astype('float64')
df["amount"]
# Out:
# Sr No
# 1       200000000.0
# 2         8048394.0
# 3        18358860.0
# 4         3000000.0
# 5         1800000.0
#            ...
# 3040      4500000.0
# 3041       825000.0
# 3042      1500000.0
# 3043            0.0
# 3044       140000.0
# Name: amount, Length: 3028, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3028 entries, 1 to 3044
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3028 non-null   str
#  1   starup       3028 non-null   str
#  2   Vertical     2857 non-null   str
#  3   subvertical  2103 non-null   str
#  4   city         2848 non-null   str
#  5   investors    3028 non-null   str
#  6   Round        3026 non-null   str
#  7   amount       3028 non-null   float64
#  8   Remarks      415 non-null    str
# dtypes: float64(1), str(8)
# memory usage: 571.8 KB

# %%
df.head(5)
# Out:
#              date                        starup             Vertical  \
# Sr No
# 1      2020-01-09                        BYJU’S               E-Tech
# 2      2020-01-13                        Shuttl       Transportation
# 3      2020-01-09                     Mamaearth           E-commerce
# 4      2020-01-02  https://www.wealthbucket.in/              FinTech
# 5      2020-01-02                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 Round       amount Remarks
# Sr No
# 1        Tiger Global Management  Private Equity Round  200000000.0     NaN
# ...

# %%
def to_inr (dollar):
    inr=dollar *82.5
    return inr/10000000

# %%
df["amount"]=df["amount"].apply(to_inr)
df["amount"]
# Out:
# Sr No
# 1       1650.000000
# 2         66.399250
# 3        151.460595
# 4         24.750000
# 5         14.850000
#            ...
# 3040      37.125000
# 3041       6.806250
# 3042      12.375000
# 3043       0.000000
# 3044       1.155000
# Name: amount, Length: 3028, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3028 entries, 1 to 3044
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3028 non-null   str
#  1   starup       3028 non-null   str
#  2   Vertical     2857 non-null   str
#  3   subvertical  2103 non-null   str
#  4   city         2848 non-null   str
#  5   investors    3028 non-null   str
#  6   Round        3026 non-null   str
#  7   amount       3028 non-null   float64
#  8   Remarks      415 non-null    str
# dtypes: float64(1), str(8)
# memory usage: 571.8 KB

# %%
df["date"].shape
# Out:
# (3028,)

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['date'].shape
# Out:
# (3028,)

# %%
#df["date"].dt.month

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3028 entries, 1 to 3044
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3028 non-null   datetime64[us]
#  1   starup       3028 non-null   str
#  2   Vertical     2857 non-null   str
#  3   subvertical  2103 non-null   str
#  4   city         2848 non-null   str
#  5   investors    3028 non-null   str
#  6   Round        3026 non-null   str
#  7   amount       3028 non-null   float64
#  8   Remarks      415 non-null    str
# dtypes: datetime64[us](1), float64(1), str(7)
# memory usage: 541.9 KB

# %%
df.drop('Remarks', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3028 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3028 non-null   datetime64[us]
#  1   starup       3028 non-null   str
#  2   Vertical     2857 non-null   str
#  3   subvertical  2103 non-null   str
#  4   city         2848 non-null   str
#  5   investors    3028 non-null   str
#  6   Round        3026 non-null   str
#  7   amount       3028 non-null   float64
# dtypes: datetime64[us](1), float64(1), str(6)
# memory usage: 513.2 KB

# %%
df = df.dropna(subset= ['date','starup','Vertical','city','investors','Round','amount'])
df.shape
# Out:
# (2846, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 2846 entries, 1 to 2873
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2846 non-null   datetime64[us]
#  1   starup       2846 non-null   str
#  2   Vertical     2846 non-null   str
#  3   subvertical  2095 non-null   str
#  4   city         2846 non-null   str
#  5   investors    2846 non-null   str
#  6   Round        2846 non-null   str
#  7   amount       2846 non-null   float64
# dtypes: datetime64[us](1), float64(1), str(6)
# memory usage: 489.9 KB

# %%
df.to_csv("final_version_1.csv",index=False)

# %%
# slit investor name

# %%
df['investors'].str.split(',')
# Out:
# Sr No
# 1                               [Tiger Global Management]
# 2                             [Susquehanna Growth Equity]
# 3                                 [Sequoia Capital India]
# 4                                        [Vinod Khatumal]
# 5                               [Sprout Venture Partners]
#                               ...
# 2869                                      [SAIF Partners]
# 2870    [Sumit Jain,  Aprameya Radhakrishna,  Alok Goe...
# 2871                                         [Rainmatter]
# 2872                                        [The HR Fund]
# 2873          [Bessemer Venture Partners,  SAIF Partners]
# Name: investors, Length: 2846, dtype: object

# %%
df['investors'].str.split(',').sum()
# Out:
# ['Tiger Global Management',
#  'Susquehanna Growth Equity',
#  'Sequoia Capital India',
#  'Vinod Khatumal',
#  'Sprout Venture Partners',
#  'Chiratae Ventures',
#  'Ant Financial',
#  'Sathguru Catalyzer Advisors',
#  'Ping An Global Voyager Fund',
#  'Mumbai Angels',
#  ' Ravikanth Reddy',
#  'SAIF Partners',
#  ' Spring Canter Investment Ltd.',
#  'Paytm',
#  ' NPTK',
#  ' Sabre Partners and Neoplux',
#  'Vertex Growth Fund',
#  'Undisclosed',
#  'Ruizheng Investment',
#  'Manipal Education and Medical Group (MEMG)',
#  'SoftBank Vision Fund',
#  'Sequoia',
#  ' CapitalG',
#  ' Accel',
#  'Sauce.vc',
#  ' Rainforest Ventures',
#  'Prime Venture Partners',
#  ' LetsVenture',
#  ' PS1 Venture and GlobalLogic co-founder Rajul Garg',
#  'RB Investments',
#  'DG Daiwa Ventures',
#  ' DG Incubation',
#  'Trifecta Capital Advisors',
#  'FinTech',
#  'Dream Incubator',
#  'Altimeter Capital',
#  ' Sutter Hill Ventures',
#  'Startup Buddy',
#  'Amour Infrastructure',
# ...

# %%
sorted(set(df['investors'].str.split(',').sum()))
# Out:
# ['',
#  ' & Others',
#  ' 100 Co-founders Lab and others.',
#  ' 122 West Ventures',
#  ' 1Crowd',
#  ' 3ONE4 Capital Advisors',
#  ' 3one4 Capital',
#  ' 3one4 Capital Advisors LLP',
#  ' 500 Start-Ups',
#  ' 500 Startups',
#  ' 500 Startups & Other HNIs',
#  ' 50K Ventures & others',
#  ' 91SpringBoard',
#  ' 91springboard',
#  ' ABB Technology Ventures',
#  ' ABCOM Investments',
#  ' AECAL',
#  ' AET Fund',
#  ' AL Nour International Holdings and Mark V Investments',
#  ' ASP Consulting',
#  ' AVN Business Solutions',
#  ' Aarin Capital',
#  ' Aarin Capital & Others',
#  ' Aaruha Technology Fund',
#  ' Abaran Deep',
#  ' Abhai S. Rao',
#  ' Abhay Singhal',
#  ' Abhijit Bhandari',
#  ' Abhinav Patodia',
#  ' Abhinav Sinha',
#  ' Abhishek Acharya',
#  ' Abhishek Goyal',
#  ' Abhishek Gupta',
#  ' Abhishek Jain',
#  ' Abhishekh Goyal',
#  ' Abstract Ventures',
#  ' Abu Farhan Azmi',
#  ' Accel',
#  ' Accel India',
#  ' Accel Partner',
#  ' Accel Partners',
# ...

# %%
df[df["investors"].str.contains('Mumbai Angels Network')]
# Out:
#             date       starup    Vertical  \
# Sr No
# 234   2018-06-11   Theranosis  Healthcare
# 394   2018-01-05         WOTU  E-commerce
# 457   2017-12-14      WeDoSky  Technology
# 1080  2017-01-18  Vahdam Teas   eCommerce
#
#                                             subvertical       city  \
# Sr No
# 234                    Specialised diagnostics Platform  Hyderabad
# 394                                  Food and Beverages  Bengaluru
# 457    Provides Business Insights using Drone Imaginary      Delhi
# 1080                                 Online Tea etailer  New Delhi
#
#                                                investors  \
# Sr No
# 234                                Mumbai Angels Network
# 394                Claris Capital, Mumbai Angels Network
# 457                                Mumbai Angels Network
# 1080   Mumbai Angels Network, Fireside Ventures, Sing...
#
#                       Round  amount
# Sr No
# 234     Seed/ Angel Funding  0.0000
# ...

# %%
df[df["investors"].str.contains('IDG Venture')].head()[["date","starup","Vertical","Round","amount"]]
# Out:
#             date    starup           Vertical           Round      amount
# Sr No
# 102   2019-04-13   Tripoto       Social Media        Series B   29.628844
# 223   2018-07-30  Cure Fit  Consumer Internet  Private Equity  990.000000
# 253   2018-06-26  Sigtuple         Healthcare  Private Equity  156.750000
# 259   2018-05-02   Bizongo  Consumer Internet  Private Equity  181.500000
# 310   2018-04-26     POPxo         Technology  Private Equity   45.375000

# %%
df[df['investors'].str.contains('IDG Venture')].groupby("starup")

# %%
df[df['investors'].str.contains('IDG Venture')].groupby("starup")['amount'].sum().sort_values(ascending=False)
# Out:
# starup
# Cure Fit                 990.000000
# Lenskart                 495.000000
# Bizongo                  206.250000
# CureFit                  206.250000
# Sigtuple                 204.600000
# Fintellix                123.750000
# Curefit                  123.750000
# Xpressbees               103.125000
# FirstCry.com              82.500000
# Uniphore                  72.600000
# POPxo                     70.950000
# \\xc2\\xa0CloudCherry     49.500000
# HealthifyMe               49.500000
# Flyrobe                   43.725000
# Aasaanjobs                41.250000
# RentMojo                  41.250000
# Vayana                    33.000000
# Agrostar                  33.000000
# PlaySimple                33.000000
# Blowhorn                  30.112500
# Tripoto                   29.628844
# Active.ai                 24.750000
# Heckyl                    22.275000
# CreditMantri              20.625000
# eShakti                   18.975000
# POPxo.com                 16.500000
# ...

# %%
df[df['investors'].str.contains('IDG Venture')].groupby('Vertical')["amount"].sum().sort_values(ascending= False).plot(kind='pie')
# Out:
# <Axes: >

# %%
df[df['investors'].str.contains('IDG Venture')].groupby('city')["amount"].sum().sort_values(ascending= False).plot(kind='pie')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#             date                        starup             Vertical  \
# Sr No
# 1     2020-01-09                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-01-09                     Mamaearth           E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/              FinTech
# 5     2020-01-02                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 Round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  1650.000000
# ...

# %%
df[df['investors'].str.contains('IDG Venture', case=False, na=False)].groupby('city')["amount"].sum().sort_values(ascending=False).head(5).plot(kind='pie')
# Out:
# <Axes: >

# %%
df['year']=df["date"].dt.year

# %%
df[df['investors'].str.contains('IDG Venture', case=False, na=False)].groupby('year')["amount"].sum()
# Out:
# year
# 2015     332.062500
# 2016    1051.050000
# 2017     487.987500
# 2018    1373.625000
# 2019      29.628844
# Name: amount, dtype: float64

# %%
df[df['investors'].str.contains('IDG Venture', case=False, na=False)].groupby('year')["amount"].sum().plot()
# Out:
# <Axes: xlabel='year'>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 2846 entries, 1 to 2873
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2846 non-null   datetime64[us]
#  1   starup       2846 non-null   str
#  2   Vertical     2846 non-null   str
#  3   subvertical  2095 non-null   str
#  4   city         2846 non-null   str
#  5   investors    2846 non-null   str
#  6   Round        2846 non-null   str
#  7   amount       2846 non-null   float64
#  8   year         2846 non-null   int32
# dtypes: datetime64[us](1), float64(1), int32(1), str(6)
# memory usage: 501.0 KB

# %%
df.loc[df['amount'] == 0, 'amount'] = np.random.randint(10, 101, size=(df['amount'] == 0).sum())

# %%
df['amount'] == 0
# Out:
# Sr No
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 2869    False
# 2870    False
# 2871    False
# 2872    False
# 2873    False
# Name: amount, Length: 2846, dtype: bool
