# %% [markdown]
# performace critical problem

# %% [markdown]
# # if support 1st in 1st out problem

# %% [markdown]
# ### Step
#  * take a empty array
#       a. take 2 index front and rear point at same location -1
#       b insert 1st element --< front and rear --> 0
#  * inter 2nd element Rear = rear + 1;
#       a. check also for the over flow
#  * Delete = front = front+1 ; (under flow )
#  * in python list is dynamic ( grows automatically )
#  * insertion at the end append (at the end )

# %% [markdown]
# only thing u need to check in python is that under flow rest is handled by python itself.
# append function also

# %% [markdown]
# # pop()
#  * in python when u pop the function if shift automatically
#  * pop (0) deleteion at the beging

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Working of Is empty
#     * Q1.isempty & Q2.isempty
#     * 2 object are made then
#         * is q1.isEmpty() & Q2.isempty

# %%
class Queue:
    
    def __init__(self):
        self.items= [] # self uss object ko represent karta hai jisko call kare ge 

    
    def isEmpty (self):
        return len (self.items )== 0 
    
    
    def inster(self,value):
        self.items.append(value) # no need to check overflow here due to dynamic array 
    
    def delete( self):
        if ( self.isEmpty()):
            print("empty ")
        else:
            return self.items.pop(0)

# %%
q = Queue()  # object created for the class queue
q.inster(10)
q.inster(100)
q.inster(1000)
q.inster(10000)
q.delete()
q.delete()
q.delete()
q.delete()
q.delete()
# Out:
# empty

# %% [markdown]
# # Double ended QUeue

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Insert at 1st
#  * we need to check the index of 1st element
#  * if (front >0 ) someting if at 2 and also rear at 4
#  * front = front -1 move 30
#  * You can't insert at 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Delete at last
#     * rear = rear -1

# %%
class DoubleQueue:
    
    def __init__(self):
        self.items= [] # self uss object ko represent karta hai jisko call kare ge 
    
    def isEmpty (self):
        return len (self.items )== 0 
    
    
    def insteAtEnd(self,value):
        self.items.append(value) # no need to check overflow here due to dynamic array 
    
    def deleteatfront( self):
        if ( self.isEmpty()):
            print("empty ")
        else:
            return self.items.pop(0)
        
    def insertAtFront(self, value):
        self.items.insert(0,value)

    def deleteAttheend(self):
        if ( self.isEmpty()):
            print("empty ")
        else:
            return self.items.pop()
        
    def view(self):
        return self.items

# %%
dp = DoubleQueue()
dp.insteAtEnd(40)
dp.insertAtFront(20)
dp.insteAtEnd(50)
dp.insertAtFront(10)
dp.view()
# Out:
# [10, 20, 40, 50]

# %%
dp.deleteAttheend()
dp.view()
# Out:
# [10, 20, 40]
