# %%
class stack:
    def __init__(self ):
        # step 1 create a empty list 
            # jasse ham stack nam ka insilisation hoga
            # wahi pe s nam empty list ban jaye ga as __init__ function
        self.s = [] # empty list 

    # function - > to find, many elements are in the list( stack )
    def length(self):
        return len(self.s)# stack is interally list 
    
    # now we will use push or pop
    # instering( push )
    # make a stack (S) 
    # 10 --> s(0) top = 0 , top =+ 1 
    # 20 --> s(1) top = 1 , top =+ 1 top  = 2 
    # we will use append which alreay do the same at the last

# take notes from below 

    def push (self, value):
        self.s.insert(0,value) # it taking help of instert fucntion


# to see what's inside

    def peak(self):
        if len(self.s)==0 :# just in case if this is empty 
            raise Exception("Stack is empty")
        else:
            return self.s[0]
# pop the item   
    def poper(self):
        if len(self.s)==0 :# just in case if this is empty 
            raise Exception("Stack is empty")
        else:
            return self.s.pop(0) # top the line  # this is pop fucntion
        
    def staked(self):
        return self.s

stk = stack()
#stk.poper()
stk.push(10)
stk.push(20)
stk.push(20)
stk.push(30)
stk.staked()
stk.peak()
stk.poper()
stk.staked()
stk.poper()
stk.poper()
stk.staked()
# Out:
# [10]

# %% [markdown]
# your can also use insert
# using append function while working with the list

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # reverse oder
#     * u can insert in reverse oder
#     * insert at 0 index always
#     * don't have to worry where is our last element

# %% [markdown]
# # insert function
#     * insert(address and value )
#     * will shift automatic up
#     * so in this  our last element will becaome 1st
#     * and our s(0) will alwasy be the 1st element

# %% [markdown]
# ![image.png](attachment:image.png)
