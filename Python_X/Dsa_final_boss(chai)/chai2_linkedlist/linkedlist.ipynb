# %%
class Node:
    def __init__(self, info, next= None ):  #made a constructor # self will store the adress of the variable we are making  
        self.data = info
        self.next = next # by default none hai 

class SignlyLinkedlist:
    def __init__(self, head =None):
        self.head = head # head made of constructor
    
    
    def insertAtEnd(self,value ): # slef is passed jo batta sake to call the adress which is stored in slef 
        temp = Node(value) # last node ke liye value passed 
        if( self.head != None ): # head jab takh none na ho jaye tab takh loop 
            t1 = self.head # head update ho gya 
            while ( t1.next != None ):
                t1 = t1.next # asse kare ke last none thak
            t1.next = temp # tempraory node ka adrress
        else: #  agar head me none hai head --> temp 
            self.head = temp 

    def insterAtbegning(self,value):
        temp = Node(value) 
        temp.next= self.head
        self.head= temp

    def insteratthemiddle(self,value,x ):
        temp = Node(value) # jo value ham sab pass kar rahe hai 
        # ^ ^ pointing towards 40 with adress of none
        t1= self.head # default pointitng towards at 10 
        while( t1.next != None):   # run till last location
            if(t1.data == x ): # reaced at the location poitnitng at t1 
                temp.next = t1.next
                t1.next = temp 
            t1 = t1.next

            
    #         # ''' at 1st we need to link the data with the 40 --> 30 
    #         #  if we don't the link will break 
    #         #  we will lost 30  '''
    def deleteLL(self,value):
        t1= self.head
        prev = t1

        # for deleting 1st vlaue  
        
        if (t1.data == value):
            self.head = t1.next

        while(t1.next != None):
            if(t1.data == value):
                prev.next = t1.next
                break
            else:
                prev = t1
                t1 = t1.next
        if(t1.data == value):
            prev.next = None       






    def printLL (self):
        t1 = self.head # head update ho gya 
        while ( t1.next != None ):
                print(t1.data)# just before last location 
                t1 = t1.next
        print(t1.data) # printing last location 


obj = SignlyLinkedlist()
obj.insertAtEnd(10)
obj.insertAtEnd(20)
obj.insertAtEnd(30)
obj.insterAtbegning(5)
obj.insteratthemiddle(40,20) # "40 insert karna hai 20 ke baad me 
obj.deleteLL(5)
obj.printLL()
# Out:
# 10
# 20
# 40
# 30

# %%
class Node:
    def __init__(self, info, next= None ):  #made a constructor # self will store the adress of the variable we are making  
        self.data = info
        self.next = next # by default none hai 

class SignlyLinkedlist:
    def __init__(self, head =None):
        self.head = head # head made of constructor
    
    
    def insertAtEnd(self,value ): # slef is passed jo batta sake to call the adress which is stored in slef 
        temp = Node(value) # last node ke liye value passed 
        if( self.head != None ): # head jab takh none na ho jaye tab takh loop 
            t1 = self.head # head update ho gya 
            while ( t1.next != None ):
                t1 = t1.next # asse kare ke last none thak
            t1.next = temp # tempraory node ka adrress
        else: #  agar head me none hai head --> temp 
            self.head = temp 

    def insterAtbegning(self,value):
        temp = Node(value) 
        temp.next= self.head
        self.head= temp

    def insteratthemiddle(self,value,x ):
        temp = Node(value) # jo value ham sab pass kar rahe hai 
        # ^ ^ pointing towards 40 with adress of none
        t1= self.head # default pointitng towards at 10 
        while( t1.next != None):   # run till last location
            if(t1.data == x ): # reaced at the location poitnitng at t1 
                temp.next = t1.next
                t1.next = temp 
            t1 = t1.next

            
    #         # ''' at 1st we need to link the data with the 40 --> 30 
    #         #  if we don't the link will break 
    #         #  we will lost 30  '''
    def deleteLL(self,value):
        t1= self.head
        prev = t1

        # for deleting 1st vlaue  
        
        if (t1.data == value):
            self.head = t1.next

        while(t1.next != None):
            if(t1.data == value):
                prev.next = t1.next
                break
            else:
                prev = t1
                t1 = t1.next
        if(t1.data == value):
            prev.next = None       






    def printLL (self):
        t1 = self.head # head update ho gya 
        while ( t1.next != None ):
                print(t1.data)# just before last location 
                t1 = t1.next
        print(t1.data) # printing last location 


obj = SignlyLinkedlist()
obj.insertAtEnd(10)
obj.insertAtEnd(20)
obj.insertAtEnd(30)
obj.insterAtbegning(5)
obj.insteratthemiddle(40,20) # "40 insert karna hai 20 ke baad me 
obj.deleteLL(5)
obj.printLL()
# Out:
# 10
# 20
# 40
# 30
