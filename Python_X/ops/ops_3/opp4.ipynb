# %% [markdown]
# # aggreagation

# %%
class Customer:
    def __init__(self, name, gender, address):
        self.name = name  # text 
        self.gender = gender  # male or female
        self.address = address  # complex - pincode /phone / landmark / city 
    
    def print_address(self):
        # public
        # print(self.address.pincode, self.address.city, self.address.state)
        # private
        print(self.address.pincode, self.address.get_city(), self.address.state)
    
    def edit_profile(self, new_name, new_city, new_pincode, new_state):
        self.name = new_name  # text 
        self.address.edit_address(new_pincode, new_city, new_state)

class Address:
    def __init__(self, pincode, city, state):  # complex - pincode / phone / landmark / city
        self.__city = city
        self.pincode = pincode
        self.state = state  # Removed comma - was creating a tuple
    
    def get_city(self):
        return self.__city  # Removed comma - was returning a tuple
    
    def edit_address(self, new_pincode, new_city, new_state):
        self.pincode = new_pincode  # Fixed: changed self.pin to self.pincode
        self.__city = new_city
        self.state = new_state

# Usage
address1 = Address('800020', 'patna', 'bihar')
cust = Customer('name', 'gender', address1)
cust.edit_profile("manisha", 'ludhiana', '11111', 'punjab')  # Fixed parameter order
cust.print_address()
# Out:
# 11111 ludhiana punjab

# %% [markdown]
# # no attribute can acess private class

# %%
cust.print_adress()
# Out:
# 800020 ('patna',) ('bihar',)

# %%
#partent class
class User:
    def __init__(self): # constrctor 
        self.name = 'nitish'

    def loging(self): # non private method 
        print('login')
# user passed then its a child class 
class Student(User):
    #def __init__(self):  # error 
        #self.rollno=100
    # method overrrideing
    ''' you have to remove construstor 
        -- reason because its inherite the parent constructor 
        -- can use non private function 
        -- non private fuincation 
        '''
    ''' note 
        -- > 1st it will look for the constructor in child class 
                - if not then will be able to use parent class constructor 
        -- > 2nd why i am getting error in s.name() # child 
            -- due constructor is avaiable 
            -- no parent called  '
            -- no name varaibale called 
            -- so the errror     
    '''
    def enroll(self):
        print("enrolled")
u=User()
s=Student()

# %%
s.loging() # parent  class attribute 
u.loging() # parent class attribute 

# child 
s.name
# Out:
# login
# login
# 'nitish'

# %% [markdown]
# # child --> parent
#     - ->  child can acesss all attribute of parent

# %%
class Phone: 
    def __init__(self,Price, brand, camera ):
        print("Inside phone constructor")
        self.price =Price
        self.brand = brand
        self.camera = camera
    def buy(self ):
        print("Buying  a new Phone")
class SmartPhone(Phone ):
    pass 
s = SmartPhone(20000, " MI", 48)
print(s.brand)
print(s.price)
print(s.camera)
s.buy()
# Out:
# Inside phone constructor
#  MI
# 20000
# 48
# Buying  a new Phone

# %% [markdown]
# # child have a constructor
#
#
#
# ##### EG

# %%
class Phone: 
    def __init__(self,Price, brand, camera ):
        print("Inside phone constructor")
        self.price =Price
        self.brand = brand
        self.camera = camera
    def buy(self ):
        print("Buying  a new Phone")
class SmartPhone(Phone ):
    def __init__(self, os , ram ):
        self.os = os 
        self.ram = ram 
        ''' this will print because Smartphone 
            constructor has a file  
        '''
        print("Inside smart phone constructor")  #
    def buy (self ):
        print("Buying  a new Smart Phone")
s= SmartPhone("Android ", "10 gb ")
# error 
#print(s.brand)
# Out:
# Inside smart phone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 20
#      18         print("Buying  a new Smart Phone")
#      19 s= SmartPhone("Android ", "10 gb ")
# ---> 20 print(s.brand)
#
# AttributeError: 'SmartPhone' object has no attribute 'brand'

# %% [markdown]
# # parent(method and function )
# - child can't acess

# %%
class Phone: 
    def __init__(self,Price, brand, camera ):
        print("Inside phone constructor")
        self.__price =Price
        self.brand = brand
        self.camera = camera
    def show(self ):
        print(self.__price)
    def __showprivate(self ):
        print(self.__price)

class SmartPhone(Phone ):
    def check (self ):
        print(self.__price)
s=SmartPhone(20000,"MI",48  )
# print(s.check())
''' error due to private '''
s.brand 
'''
error due to private 
s.__showprivate()
'''
# Out:
# Inside phone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 19
#      17 ''' error due to private '''
#      18 s.brand
# ---> 19 s.__showprivate()
#
# AttributeError: 'SmartPhone' object has no attribute '__showprivate'

# %%
class Parent:
    def __init__(self,num):
        self.__num = num
    def get_num(self):
        return self.__num
class Child(Parent):
    def show(self):
        print("Inside child class")
son =Child(100)
print(son.get_num()) # 100"
son.show() #Inside child class
# Out:
# 100
# Inside child class

# %%
class Parent:
    def __init__(self,num): # no constructor called 
        self.__num= num
    def get_num(self):
        return self.__num
class Child(Parent):
    def __init__(self,val,num):# error 
        self.__val=val 
    def get_val(    self    ): 
        return self.__val
son = Child (100,10)
# print("Parent:Num",son.get_num())# error
'''due to child has its own constructor '''
print("Child: Val",son.get_val()) # 100
# Out:
# Child: Val 100

# %%
class A:
    def __init__(self):
        self.val1 = 100
    def display1 (self, val1): # this val1 is diffrent 
        print("class A ",self.val1)
        self.val1=val1 # niche se ham pass kiye 200 
        print("class A ",self.val1)
class B(A):
    def display2(self, val1):
        print("class B : ",self.val1)
obj = B()
obj.display1(200)
# Out:
# class A  100
# class A  200

# %% [markdown]
# # Method overriding
# - if parent & child has same func-->
#     - then child fuction will work
# # constructor over loading
# -  parent & child has same constructor
#     - then child will domminate here
#
#
#
# #### same story overall

# %%
class phone: 
    def __init__(self, price,brand, camera):
        print("Inside a phone constructor ")
        self.__price = price
        self.brand = brand
        self.camera = camera
    def buy(self ):
        print("Buying  a new Phone ")
class SmartPhone(phone):
    def buy(self):
        print("buying a Smartphone")

s = SmartPhone(20000, "poco", "x6 pro ")
s.buy()
# Out:
# Inside a phone constructor
# <bound method SmartPhone.buy of <__main__.SmartPhone object at 0x0000012D3C3FEBA0>>

# %% [markdown]
# # Super Keyword

# %%
class Phone: 
    def __init__(self, price, brand ,camera ):
        print(" Inside Phone constructor ")
        self.__price = price 
        self.brand = brand
        self.camera = camera
    def buy(self ):
        print("Buying a phone ")
class SmartPhone(Phone ):
    def buy (self ):
        print("buying a smartphone ")
        super().buy()
s= SmartPhone(20000,"apple ",13)
s.buy()
# Out:
#  Inside Phone constructor
# buying a smartphone
# Buying a phone

# %% [markdown]
# Above_code
# # child  &  parent --> buy ()
# - method overloading -> due to this
#     - child buy ()
# - super().buy
#     - help to call parent buy()

# %%
# video time stamp 1:18      
class Phone:
    def __init__(self,price, brand , camera ):
        print("Inside a phone constructor ")
        self.__price= price
        self.brand = brand
        self.camera = camera
    def buy (self  ):
        print ("Buying a smartphone ")
class SmartPhone(Phone ):
    def __init__(self,price, brand , camera,os ,ram  ):
        print(" check 1 Inside SmartPhone constructor ")
        super().__init__(price,brand,camera)
        self.os = os 
        self.ram = ram
        print("check 2 Inside SmartPhone constructor")
s = SmartPhone(20000,"motalarua ",12, "androind",8 )
'''price call nahi hoga private function hai 

'''
print(s.os)
print(s.ram )
# Out:
#  check 1 Inside SmartPhone constructor
# Inside a phone constructor
# check 2 Inside SmartPhone constructor
# androind
# 8

# %% [markdown]
# # Code summary
# 1. passed in smartphone =  SmartPhone(20000,"motalarua ",12, "androind",8 )
# 2. child constructor chala hai
# 3. print hua  check 1
# 4. super (). call kiye parent method ko
# 5. varaible insitalisation hua hai
# 6.  print hua check 2

# %% [markdown]
# # why super
# - u can't directly access the parent class constructor
# - use super() to acess the parent class constructor function
# - eg :- smartphone have specail thing like os and  ram
#     - but baisc phone don't have these things
# - now u have to  call the function of it

# %% [markdown]
# # Note
# can't use super outside the Class
# #### only works inside the child function

# %% [markdown]
# # note that u can't acess the attribute,  only u can acess the methods

# %% [markdown]
# Inheritance in summary
# • A class can inherit from another class.
# • Inheritance improves code reuse
# • Constructor, attributes, methods get inherited to the child class
# • The parent has no access to the child class
# • Private properties of parent are not accessible directly in child class
# • Child class can override the attributes or methods. This is called method overriding
# • super() is an inbuilt function which is used to invoke the parent class methods and constructor

# %%
class Parent:
    
    def __init__(self,num):
        self.__num= num
    
    def  get_num(self):
        return self.__num
    
class child(Parent):
    
    def _init_(self,num,val):
        super().__init__(num)
        self.__val =val 

    def get_val(self):
        return self.__val
    
son =Child(100,200)
print(son.get_num()) # 100  
print(son.get_val()) # 200

# %%
# 1:33 video
# 
# 
class Parent:
    def __init__(self):
        self.num =100
class child(Parent):
    
    def __init__(self ):
        super().__init__() 
        self.var =200

    def show(self):
        print(self.num )
        print(self.var )
son = child()
son.show()
# Out:
# 100
# 200

# %% [markdown]
# step 1 :-> chiild called
# steo 2 :-> super called
# step 3 :-> parent called __>    self.num =100
# step 4: -> self var 200 from child __init__
# step 5 ashow ()

# %%
class Parent:
    def __init__(self):
        self.__num=100
    
    def show(self):
        print ("Parents",self.__num)
class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var = 10

    def show(self):
        print ("Child",self.__var )
son=child(200)
son.show()

# %% [markdown]
# child me ayye
# init kud ka constructor called hua hai
# now = 100

# %%
# Out:
# 100
# 200

# %% [markdown]
# # types of inheritance
# a. Singel inheritance
# b. Multilevel inheritance
# c. Hierarchical inheritance
# d. Multiple inheritance (Dimond Problem )
# e. Hybrid Inheritance

# %% [markdown]
# # singel Inheritance

# %%
class Phone:
    def __init__(self,price,brand,camera):
        print("inside Phone constructor ")
        self.price= price
        self.brand  = brand
        self.camera = camera
    def buy (self):
        print("Buying a smartphone")   
    

class SmartPhone(Phone ):
    def get(self,price, brand , camera,):
        print(" check 1 Inside SmartPhone constructor ")
        print(self.price, self.brand ,self. camera)    
        print("check 2 Inside SmartPhone constructor")
s=SmartPhone('100000','lava','120')
print(s.price)
# Out:
# inside Phone constructor
# 100000

# %% [markdown]
# # multilevel

# %%
class product
