# %%
class point:
    def __init__(self,x , y): # pass the cordinate 
        self.xcod = x 
        self.ycod = y
#end 
    def __str__(self):
        return '<{},{}>'.format (self.xcod , self.ycod )
    def eucliedean_dist(p1, p2):
        return ((p1.xcod-p2.xcod)**2+(p1.ycod-p2.ycod)**2)**0.5
    def shortestdist(p1 ):
        ((p1.xcod-0)**2+(p1.ycod-0)**2)**0.5

# %%
p1 = point(0,0)# pass your digit 
print(p1,'\n', p1)
p2 = point(7,1)#
print(p2,'\n',p2)
p1.eucliedean_dist(p2)
p1.shortestdist()
# Out:
# <0,0>
#  <0,0>
# <7,1>
#  <7,1>

# %%
class linecl:
    def __init__(self,A,B,C):
        self.A =A 
        self.B =B
        self.C =C
    def __str__(self):
        return '{}x {}y +{}=0'.format (self.A , self.B , self.C )
    
    def point_check(self,x,y): # note here y 
        if ((x*self.A) +  (y-self.B) +  self.C==0):
            return 'yespoint'
        else :
            return 'no point'
    def shortest_dist(self,x,y):
        numerator = abs(self.A * x + self.B * y + self.C)
        denominator = (self.A**2 + self.B**2)**0.5
        return numerator / denominator
        # x and y point coordinate
        # self A  B C are the coefficient of the equation

# %%
Line = linecl(1,1,-2)
print(Line)

Line.point_check(1,1)
# Out:
# 1x 1y +-2=0
# 'no point'

# %%
my_line = linecl(1, 1, -2)  # Represents line: 2x + 3y - 5 = 0
print(my_line)  # Output: 2x + 3y + -5=0
print(my_line.point_check(1, 1))  # Check if point (1,1) lies on the line
print(my_line.shortest_dist(1, 1))  # Calculate shortest distance from point (1,1) to the line
# Out:
# 1x 1y +-2=0
# no point
# 0.7071067811865475

# %%
class Person:

  def __init__(self,name_input,country_input):
    self.name = name_input
    self.country = country_input

  def greet(self):
    if self.country == 'india':
      print('Namaste',self.name)
    else:
      print('Hello',self.name)

# %%
p = Person('nitish','india')

# %%
p.greet()
# Out:
# Namaste nitish

# %%
p.gender
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 p.gender
#
# AttributeError: 'Person' object has no attribute 'gender'

# %%
p.gender = 'male'
p.gender
# Out:
# 'male'

# %% [markdown]
# ### Reference Variables
#
# - Reference variables hold the objects
# - We can create objects without reference variable as well
# - An object can have multiple reference variables
# - Assigning a new reference variable to an existing object does not create a new object

# %%
class Person:
  def __init__(self):
    self.name = 'nitish'
    self.gender = 'male'
p = Person()
q=p

# %% [markdown]
# # p = Person() --> it we call this
# - any how person call hota hai object ban jata hai
# - bass p uska reffrence sotre kar raha hai
# #### p is not the object
# - but p ke pass reffernce hai object ka
# - p is the reffrence varaible/ address
# - p --> looks for memeory reffrence obj (person )

# %% [markdown]
# p and q both point at same point

# %%
print(id(p))
print(id(q))
# Out:
# 1485536795280
# 1485536795280

# %% [markdown]
# - agar q ko new obje point karo ge
# - tho p ka refrence wahi point
# - means new obej ke tarf point
# - p is the reffrence variable/ address of object (person ) and q is the reference variable/address of new object (person )
# - change in every obeject

# %%
print(p.name)
print(q.name)
q.name = 'ankit'
print(q.name)
print(p.name)
# Out:
# nitish
# nitish
# ankit
# ankit

# %%
print(id(p))
print(id(q))
# Out:
# 1485536795280
# 1485536795280

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  print('Hi my name is',person.name,'and I am a',person.gender)
  p1 = Person('ankit','male')
  return p1

p = Person('nitish','male')
x = greet(p) # functrion object ko retrun kar raha hai
print(x.name)
print(x.gender)

# %% [markdown]
# # created
# same id
# --> same place in memeory for both
# --> new obeject --> same place pe point
# --> by default all object are immutable
#
#
#
# ![My Image](./im.png)

# %%
p = Person('nitish','male')
print(id(p))
p1 = greet(p)
print(id(p1))

# %% [markdown]
# p = Person('nitish','male')
# print(id(p))
# p1 = greet(p)
# print(id(p1))

# %% [markdown]
# # Encapsulation
# instance variable/attribute ke tarf point kar raha hai
# - that main tha vlaue will be pass
# - to the object ka instance variable/ attribute
# - jaissa value pass hoga wassa variable

# %%
# instance var -> python tutor
class Person:

  def __init__(self,name_input,country_input):
    self.name = name_input
    self.country = country_input

p1 = Person('nitish','india')
p2 = Person('steve','australia')

# %%
print(p1.name)
print(p2.name)
# Out:
# nitish
# steve

# %% [markdown]
# # _ _ 2 underscore make it private

# %%
class Atm:

  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    #self.menu()

  def get_balance(self): # getter 
    return self.__balance

  def set_balance(self,new_value): # settter
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
obj =Atm()
# Out:
# 2423555021120

# %%
obj.balance = 'hehehehe'

# %%
obj.create_pin()
obj.balance = 'hehehehe'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 obj.create_pin()
#       2 obj.balance = 'hehehehe'
#
# Cell In[11], line 44, in Atm.create_pin(self)
#      41 user_pin = input('enter your pin')
#      42 self.pin = user_pin
# ---> 44 user_balance = int(input('enter balance'))
#      45 self.__balance = user_balance
#      47 print('pin created successfully')
#
# ValueError: invalid literal for int() with base 10: ''

# %%
obj.withdraw()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 obj.withdraw()
#
# Cell In[11], line 71, in Atm.withdraw(self)
#      68 user_pin = input('enter the pin')
#      69 if user_pin == self.pin:
#      70   # allow to withdraw
# ---> 71   amount = int(input('enter the amount'))
#      72   if amount <= self.__balance:
#      73     self.__balance = self.__balance - amount
#
# ValueError: invalid literal for int() with base 10: ''

# %%
obj.create_pin()
obj.__balance='hehehe'
# Out:
# pin created successfully

# %%
obj.withdraw()
# Out:
# sale chor

# %% [markdown]
# # function is made private then
# _ _ balance --> _Atm_balance
# only this will _ Atm  _ balance --> then it will worK

# %%
obj=Atm()
obj.create_pin()
obj._Atm__balance = 'hehehe' # pricate data
# Out:
# 2227757261760
# pin created successfully

# %%
obj.withdraw()
# Out:
# sale chor

# %% [markdown]
# # geter and setter
# - greater
#     - private show outside
#
# - setter
#     - bhar se value change karna

# %%
obj.get_balance()
# Out:
# 0

# %%
obj.set_balance(100)

# %%
obj.get_balance()
# Out:
# 100

# %% [markdown]
# # encapsulation
# - your will protecet your varaible from being accessed by other
# - you make getter and setter method
# to protect the
# -  encapsulation = data + getter + setter
# - how make it private to protect from other
# - exopse your varaible function to other world to change though but with limitation

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

p1 = Person('nitish','male')
p2 = Person('ankit','male')
p3 = Person('ankita','female')

d = {'p1':p1,'p2':p2,'p3':p3}
L=[p1,p2,p3]
for i in L:
  print(i.name,i.gender)
for i in d:
  print(d[i].gender)
# Out:
# nitish male
# ankit male
# ankita female
# male
# male
# female

# %% [markdown]
# # Static Keyword

# %%
class Atm:

  __counter = 1

  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    # self.cid = Atm.counter >> instace varaible 
    self.cid = Atm.__counter # private 
    Atm.__counter = Atm.__counter + 1 #private 
    #self.menu()
    # Atm.__counter instace vairbale 
    # 


  # utility functions
  @staticmethod
  def get_counter():
    return Atm.__counter


  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %% [markdown]
# - Atm.get_counter() call with class
# - c1.get_counter() will give error because
#
# is not expecting any passdown value like other do with self
#   # utility functions
#   @staticmethod
#   def get_counter():
#     return Atm.__counter
