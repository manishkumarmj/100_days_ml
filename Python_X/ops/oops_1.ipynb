# %%
l= [1,2,3]
l.upper() # error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 l= [1,2,3]
# ----> 2 l.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s= 'hello'
s.append('d') # errors= 'hello world'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 s= 'hello'
# ----> 2 s.append('d')
#
# AttributeError: 'str' object has no attribute 'append'

# %%
L = [1,2,3]
print(type(L))
# Out:
# <class 'list'>

# %%
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %% [markdown]
# # class 2 type ?
#     a. built in class
#     b. user defined class

# %% [markdown]
# # constructor
# --> 1st. __init__ slef()
# --> 2nd. your will create a function inside the fucntion
# --> 3rd. decelare your varialale as self

# %% [markdown]
# # constructor --> no need to call this function when u want to excute it
# when u create the object of it ( python excute it self if object is created )

# %%
class Atm:
    # constructor
    def __init__(self): # this is the constructor  # if u will create an function / variable  then u can use it as a constructor
        self.pin =''
        self.balance=0
        self.menu() # calling menu 
    def menu(self):
        user_input = input("""
              How can i help you 
              1. Press 1 to create a pin
              2. Press 2 to change pin 
              3. Press 3 to check your balance
              4. Press 4 to withdraw
              5. send  money to swiss account modi ji dream work of 15 00 000
              """)
    
        if user_input =='1':
            #Create a pin
            self.CreatePin()
        elif user_input =="2":
            self.changePin()
        # Change pin
        elif user_input =="3":
        #Check your balance
            self.checkBalance()
            
        elif user_input == "4":
        # withdraw money
            self.withdrawMoney()
        else :
            
            exit()
    def CreatePin(self):
        user_pin = input("enter you pin")
        self.pin = user_pin

        user_balance= int(input("enter the balance "))
        self.balance=   user_balance 
        
        print("pin created carefully")
        self.menu()

    def changePin(self):
        oldPin=(input("Enter you old pin"))
        if oldPin== self.pin:
            # change to new pin
            user_pin = input("enter you pin")
            self.pin = user_pin 
            print('pin changed successfull')
            self.menu()
        else:
            print("nai karne de skata re baba")
            self.menu()
    def checkBalance(self):
        print("Your current balance --> ", self.balance) 
        self.menu()
    def withdrawMoney(self):
        withDraw = int(input("Enter the amount"))
        if(withDraw< self.balance):
            print("Your amount is withdrawed ", withDraw)
            self.balance = self.balance-withDraw
            print("Your current balance --> ", self.balance)
            self.menu()
        else:
            print("Ye garib iske maa ke chut")
            self.menu()


## object

# %%
object= Atm()
# Out:
# pin created carefully
# Ye garib iske maa ke chut
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # object
#     a. you need a object of a class which need to full the infromation from the class
#     b.

# %% [markdown]
# # object created

# %%
print(type(object))
# Out:
# <class '__main__.Atm'>

# %%
obj

# %% [markdown]
# def
