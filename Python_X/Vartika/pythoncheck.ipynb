# %% [markdown]
# • If n is even and in the inclusive range of 2 to 5, print Not Weired
# • If n is even and in the inclusive range of 6 to 20, print Wei rd
# • If n is even and greater than 20, print Not Wei rd

# %%
# 1<=n<=100
for n in range (1,101):
    # even 
    if n % 2 ==0 : 
        if (2<=n and n <= 5):print("Not Weired")
        elif (6 <= n and n <= 20):print("Weird")
        elif(20<=n):print ("Not Weird ")

    # odd    
    if n% 2 != 0 : print ("Weird")
# Out:
# Weird
# Not Weired
# Weird
# Not Weired
# Weird
# Weird
# Weird
# Weird
# Weird
# Weird
# Weird
# Weird
# Weird
# Weird
# Weird
# Weird
# Weird
# Weird
# Weird
# Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
# Weird
# Not Weird
