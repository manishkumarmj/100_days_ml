# %%
import numpy as np
import pandas as pd
pd.options.display.max_columns = None

# %% [markdown]
# ###`Q-6:` Make a dataframe of each team in IPL with details like - Team Name, Matches Played, Win%, Home Win%, Away Win%.
# Show sorted dataframe on Win%
#
# Replace old team name as new name before performing any tasks.
# ```
# Delhi Daredevils ->Delhi Capitals
# Kings XI Punjab -> Punjab Kings
# Rising Pune Supergiants -> Rising Pune Supergiant
# ```
#
# Note: Team1 represents Home team. Exclude not result matches.

# %%
url3=("https://docs.google.com/spreadsheets/d/e/2PACX-1vRy2DUdUbaKx_Co9F0FSnIlyS-8kp4aKv_I0-qzNeghiZHAI_hw94gKG22XTxNJHMFnFVKsO4xWOdIs/pub?gid=1655759976&single=true&output=csv")
ipl = pd.read_csv(url3)
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# Raw data
df1 = pd.DataFrame({'fruit': ['apple', 'banana', 'mango'], 'qty': [5, 7, 10]})

# New DataFrame with custom order
df2 = pd.DataFrame(index=['mango', 'apple', 'banana'], columns=['qty'])

# Fill from df1 by matching fruit name
df2['qty'] = df1.set_index('fruit')['qty']

print(df2)
# Out:
#         qty
# mango    10
# apple     5
# banana    7

# %%
df2
# Out:
#       A  B
# row1  1  4
# row2  2  5
# row3  3  6

# %% [markdown]
# # Series

# %%
# pd.Series(country) pass this list to convert it into serise   
# custom index pd.Series(marks,index=subjects)
# size
# dtype
# is_unique
# index
# values
# Series using read_csv
# head and tail
# value_counts
# sort_values (by='runs', ascending=True)
# sort_index
# count --> missing vlaue exclude 
# size --> missing all
# sum
# mean()
# median()
# mode()
# std()
# var() --> variance of numeric columns 
# max()
# describe()
# integer indexing
# slicing
# fancy indexing
# Editing Series using indexing 
# type conversion
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy
# drop_duplicates
# between --> vk[vk.between(51,99)].siz
# subs.clip(100,200)
# apply
