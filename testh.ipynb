# %%
import numpy as np
import pandas as pd

# %%
ipl = pd.read_csv(r'A:\AIML_DEV_FOLDER\Data visualization\pandas\session_17\ipl-matches.csv')

ipl.sample(9)
# Out:
#           ID          City        Date   Season MatchNumber  \
# 64   1304056          Pune  2022-04-02     2022          10
# 567   598058        Jaipur  2013-05-12     2013          61
# 288  1136586         Delhi  2018-04-27     2018          26
# 341  1082622       Kolkata  2017-04-28     2017          32
# 836   392238  Johannesburg  2009-05-23     2009  Semi Final
# 698   548309        Jaipur  2012-04-06     2012           4
# 47   1304073        Mumbai  2022-04-16     2022          27
# 139  1216505     Abu Dhabi  2020-11-02  2020/21          55
# 709   501264    Dharamsala  2011-05-21     2011          67
#
#                            Team1                  Team2  \
# 64                Gujarat Titans         Delhi Capitals
# 567             Rajasthan Royals    Chennai Super Kings
# 288             Delhi Daredevils  Kolkata Knight Riders
# 341        Kolkata Knight Riders       Delhi Daredevils
# 836  Royal Challengers Bangalore    Chennai Super Kings
# ...

# %%
ipl.shape
# Out:
# (950, 20)
