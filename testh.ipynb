# %%
word = "hello how are you i am fine thank you"

result = word.split(' ')
result = str.split(' ')
count_of_string = []
max = 0 
for i in result:
    count = 0
    j = len( result)
    while j>=0 :
        if i == result[j-1]:
            count += 1
            if count > 1 :
                count_of_string.append(result[i])
            else:
                pass
            j -= 1

# %%
arr = [3, 7, 2, 9, 5]
max_val = arr[0]
for num in arr:
    if num > max_val:
        max_val = num
print(max_val)  # 9

# %%
s = [3, 7, 2, 9, 5]
d = {}
for i in s.split():
    if i in d:
      d[i] = d[i] + 1
    else:
      d[i] = 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 s = [3, 7, 2, 9, 5]
#       2 d = {}
# ----> 3 for i in s.split():
#       4     if i in d:
#       5       d[i] = d[i] + 1
#
# AttributeError: 'list' object has no attribute 'split'
