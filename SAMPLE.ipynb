# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
spoti =pd.read_csv('A:/AIML_DEV_FOLDER\ML_X/sefl_Learn/Day_21_bivariate/spotify_churn_dataset.csv')

# %%
# Out:
#       user_id  gender  age country subscription_type  listening_time  \
# 663       664  Female   23      DE           Premium             230
# 2704     2705  Female   48      DE           Student             184
# 194       195    Male   59      PK           Student             161
# 721       722  Female   46      FR           Student              53
# 225       226  Female   40      FR              Free              66
# ...       ...     ...  ...     ...               ...             ...
# 3149     3150   Other   19      FR           Premium             266
# 5205     5206  Female   48      UK              Free             282
# 6582     6583    Male   35      IN           Premium              67
# 2925     2926    Male   59      AU            Family              33
# 7929     7930  Female   26      CA           Student             262
#
#       songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# ...
