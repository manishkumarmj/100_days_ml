# %% [markdown]
# ### Writing to a file

# %%
f=open('Smaple.txt', 'w') # file here not created yet
# we will name it Smaple.txt, --> w write or read 
f.write('Mera nam manish')
f.write('\n') # this will write 
f.close()

# %%
f=open('Smaple1.txt', 'w')
f.write('\n hello world')
f.write('\n this is a new line in the file')
f.close()
