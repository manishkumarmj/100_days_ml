# %% [markdown]
# - apply
# - astype
# - between
# - between --> vk[vk.between(51,99)].siz
# - clip
# - copy
# - count --> missing vlaue exclude
# - corr
# - .drop(columns=)
# - describe
# - drop_duplicates
# - duplicated
# - dropna
# - dtype
# - Editing Series using indexing
# - fancy indexing
# - fillna
# - head and tail
# - index
# - insert
# - info
# - integer indexing
# - is_unique
# - isna() isnull / notnull / hasnans — nan value missing value
# - isin
# - max
# - mean
# - median
# - mode
# - nlargest
# - nsmallest
# - nunique() → returns integer count of unique values
# - pd.Series(country) pass this list to convert it into serise
# - custom index pd.Series(marks,index=subjects)
# - read_csv
# - rank
# - replace(your, value,inplace=True )
# - rename
# - rename_index -> rename
# - reset_index
# - size
# - size --> missing all
# - slicing
# - sort_index
# - set_index
# - sort_values (by='runs', ascending=True)
# - std
# - subs.clip(100,200)
# - sum
# - data.columns.tolist()
# - type( )
# - type conversion
# - unique()  → returns array of unique values
# - value_counts
# - values
# - var() --> variance of numeric columns

# %% [markdown]
# # ADvance pandas

# %% [markdown]
# ## Group by
#  - .first() --> 1st movie of every grpup
#  - .last()  --> last movie of every grpup
#  - .nth()   --> that movie of every group
#  - genres.groups, eg -> action --< 2 index >   adventure --< 21 index >
#  - genres.sample(2,replace=True), if some don't have value then if will be repeated
#
# ### agg
#     isme ham niche wale 2 method bhei pass kar sakte hai
#     jasse ke 'Runtime':['min', 'max']
#  -  genres.agg(
#     {  'Runtime':'mean', 'IMDB_Rating':'mean', 'No_of_Votes':'sum', 'Gross':'sum', 'Metascore':'min'
#     })
#     yaha pe tum 3 se 4 built in fucntion pass kar sakte ho
#  - genres.agg(['min','max','mean','sum' ]) -->
#  asse bhie kare sakte hai
