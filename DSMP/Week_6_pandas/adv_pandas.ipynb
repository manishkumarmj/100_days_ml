# %% [markdown]
#  - pd.concat (axis=1) for horizontall
#
#  - df.concat
#  - ignore_index
#  - df.append
#  - mullitindex -> fetch using loc and iloc loc for lablel
#  - concat dataframes horizontally
