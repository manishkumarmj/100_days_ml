# %%
import pandas as pd
import numpy as np

# %%
m = pd.read_csv("imdb-top-1000.csv")
t= pd.read_csv("train - train.csv")

# %%
m.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
group = m.groupby("Genre")
t_g= t.groupby("Pclass")

# %%
group.sum()
# Out:
#                                                 Series_Title  \
# Genre
# Action     The Dark KnightThe Lord of the Rings: The Retu...
# Adventure  InterstellarBack to the FutureInglourious Bast...
# Animation  Sen to Chihiro no kamikakushiThe Lion KingHota...
# Biography  Schindler's ListGoodfellasHamiltonThe Intoucha...
# Comedy     GisaengchungLa vita è bellaModern TimesCity Li...
# Crime      The GodfatherThe Godfather: Part II12 Angry Me...
# Drama      The Shawshank RedemptionFight ClubForrest Gump...
# Family     E.T. the Extra-TerrestrialWilly Wonka & the Ch...
# Fantasy                Das Cabinet des Dr. CaligariNosferatu
# Film-Noir   The Third ManThe Maltese FalconShadow of a Doubt
# Horror     PsychoAlienThe ThingThe ExorcistNight of the L...
# Mystery    MementoRear WindowVertigoShutter IslandKahaani...
# Thriller                                     Wait Until Dark
# Western    Il buono, il brutto, il cattivoOnce Upon a Tim...
#
# ...

# %%
t_g.sum()
# Out:
#         PassengerId  Survived  \
# Pclass
# 1             99705       136
# 2             82056        87
# 3            215625       119
#
#                                                      Name  \
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       Nasser, Mrs. Nicholas (Adele Achem)Hewlett, Mr...
# 3       Braund, Mr. Owen HarrisHeikkinen, Miss. LainaA...
#
#                                                       Sex      Age  SibSp  \
# Pclass
# 1       femalefemalemalefemalemalemalemalefemalemalema...  7111.42     90
# 2       femalefemalemalemalemalemalefemalefemalefemale...  5168.83     74
# 3       malefemalemalemalemalefemalefemalemalemalefema...  8924.92    302
#
#         Parch                                             Ticket        Fare  \
# Pclass
# 1          77  PC 175991138031746311378311378819950PC 17601PC...  18177.4125
# 2          70  237736248706244373239865248698C.A. 2457911668S...   3801.8417
# ...

# %%
tg= t.groupby("Embarked")

# %%
tg.sum()
# Out:
#           PassengerId  Survived  Pclass  \
# Embarked
# C               74820        93     317
# Q               32178        30     224
# S              289496       217    1514
#
#                                                        Name  \
# Embarked
# C         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Q         Moran, Mr. JamesRice, Master. EugeneMcGowan, M...
# S         Braund, Mr. Owen HarrisHeikkinen, Miss. LainaF...
#
#                                                         Sex       Age  SibSp  \
# Embarked
# C         femalefemalefemalemalemalefemalemalemalefemale...   4005.92     65
# Q         malemalefemalefemalefemalefemalemalefemalefema...    786.50     33
# S         malefemalefemalemalemalemalefemalefemalefemale...  16312.75    368
#
#           Parch                                             Ticket  \
# Embarked
# C            61  PC 1759923773626492631PC 17601PC 17569PC 17604...
# ...

# %%
t.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
tg[['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']].std()
# Out:
#           PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Embarked
# C          259.454201  0.498608  0.944100  15.434860  0.557213  0.660481
# Q          253.646282  0.490860  0.369274  16.915396  0.979105  0.656999
# S          256.942044  0.473037  0.789402  14.143192  1.216600  0.853253
#
#                Fare
# Embarked
# C         83.912994
# Q         14.188047
# S         35.887993

# %%
plcass= t.groupby("Pclass")
plcass

# %%
plcass["Survived"].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %% [markdown]
# extract the fare by each calss

# %%
# both are same but 1st one is faster

plcass["Survived"].sum() 
plcass.sum()["Survived"]
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %% [markdown]
# WHICH CALLS has much higher fare collection

# %%
plcass["Fare"].sum()
# Out:
# Pclass
# 1    18177.4125
# 2     3801.8417
# 3     6714.6951
# Name: Fare, dtype: float64

# %%
plcass["Survived"].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64
