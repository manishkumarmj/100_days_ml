# %% [markdown]
# ## **Questions based on Titanic Dataset:**

# %%
import pandas as pd

url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQjh5HzZ1N0SU7ME9ZQRzeVTaXaGsV97rU8R7eAcg53k27GTstJp9cRUOfr55go1GRRvTz1NwvyOnuh/pub?gid=1562145139&single=true&output=csv"
t = pd.read_csv(url)

# %%
t['Pclass'] = t['Pclass'].replace({1: 'AC', 2: 'Sleeper', 3: 'General'})
t['Embarked'] = t['Embarked'].replace({'C': 'France', 'Q': 'Ireland', 'S': 'England'})

# %%
t.head()
# Out:
#    PassengerId  Survived   Pclass  \
# 0            1         0  General
# 1            2         1       AC
# 2            3         1  General
# 3            4         1       AC
# 4            5         0  General
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN  England
# 1      0          PC 17599  71.2833   C85   France
# 2      0  STON/O2. 3101282   7.9250   NaN  England
# 3      0            113803  53.1000  C123  England
# 4      0            373450   8.0500   NaN  England

# %% [markdown]
# ### `Q-1:` Using `groupby` make groups using the `"Pclass"` column and find out the average age and total number of missing values in the `"Age"` column for every group.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bogytype= t.groupby('Pclass')
for bogy in list(bogytype.groups.keys()):
    print("Class",bogy," average Age : -> ", round(bogytype.get_group(bogy)["Age"].mean(),2),"Total misssing value ", {bogytype.get_group(bogy)['Age'].isna().sum()})
# Out:
# Class AC  average Age : ->  38.23 Total misssing value  {np.int64(30)}
# Class General  average Age : ->  25.14 Total misssing value  {np.int64(136)}
# Class Sleeper  average Age : ->  29.88 Total misssing value  {np.int64(11)}

# %%
bogytype.groups
# Out:
# {'AC': [1, 3, 6, 11, 23, 27, 30, 31, 34, 35, 52, 54, 55, 61, 62, 64, 83, 88, 92, 96, 97, 102, 110, 118, 124, 136, 137, 139, 151, 155, 166, 168, 170, 174, 177, 185, 187, 194, 195, 209, 215, 218, 224, 230, 245, 248, 252, 256, 257, 258, 262, 263, 268, 269, 270, 273, 275, 284, 290, 291, 295, 297, 298, 299, 305, 306, 307, 309, 310, 311, 318, 319, 325, 329, 331, 332, 334, 336, 337, 339, 341, 351, 356, 366, 369, 370, 373, 375, 377, 380, 383, 390, 393, 412, 430, 434, 435, 438, 445, 447, ...], 'General': [0, 2, 4, 5, 7, 8, 10, 12, 13, 14, 16, 18, 19, 22, 24, 25, 26, 28, 29, 32, 36, 37, 38, 39, 40, 42, 44, 45, 46, 47, 48, 49, 50, 51, 57, 59, 60, 63, 65, 67, 68, 69, 71, 73, 74, 75, 76, 77, 79, 80, 81, 82, 85, 86, 87, 89, 90, 91, 93, 94, 95, 100, 101, 103, 104, 105, 106, 107, 108, 109, 111, 112, 113, 114, 115, 116, 119, 121, 125, 126, 127, 128, 129, 130, 131, 132, 138, 140, 141, 142, 143, 146, 147, 152, 153, 154, 156, 157, 158, 159, ...], 'Sleeper': [9, 15, 17, 20, 21, 33, 41, 43, 53, 56, 58, 66, 70, 72, 78, 84, 98, 99, 117, 120, 122, 123, 133, 134, 135, 144, 145, 148, 149, 150, 161, 178, 181, 183, 190, 191, 193, 199, 211, 213, 217, 219, 221, 226, 228, 232, 234, 236, 237, 238, 239, 242, 247, 249, 259, 265, 272, 277, 288, 292, 303, 308, 312, 314, 316, 317, 322, 323, 327, 340, 342, 343, 344, 345, 346, 357, 361, 385, 387, 389, 397, 398, 399, 405, 407, 413, 416, 417, 418, 426, 427, 432, 437, 439, 440, 443, 446, 450, 458, 463, ...]}

# %% [markdown]
# titanic_df = pd.DataFrame({
#     'Passenger': ['John', 'Mary', 'Bob', 'Anna', 'Tom'],
#     'Pclass': [1, 2, 1, 3, 2],
#     'Age': [25, 30, 22, 40, 28]
# })
#
#
# Pclass_group = titanic_df.groupby('Pclass')
#
#
# Pclass_group.groups
# {
#     1: [0, 2],    # Pclass=1 → rows 0 (John) and 2 (Bob)
#     2: [1, 4],    # Pclass=2 → rows 1 (Mary) and 4 (Tom)
#     3: [3]        # Pclass=3 → row 3 (Anna)
# }
# What .keys() does:
# provide there class name
# Pclass_group.groups.keys() dict_keys([1, 2, 3])   # just the group names (1, 2, 3)

# %% [markdown]
# ### `Q-2:` Using `groupby` make groups using the `"Pclass"` column and fill every group's `"Embarked"` column's missing values with the mode value of that group. After that, print every group's `"Embarked"` column's value counts in ascending order.

# %%
pclass_groups = t.groupby("Pclass")
for i in pclass_groups.groups.keys():
    mode = pclass_groups.get_group(i)["Embarked"].mode()# ye list ac me kitna 
    pclass_groups.get_group(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 pclass_groups   = t.groupby("Pclass")
# ----> 2 for i in list(pclass_groups.groupby.keys()): # ye list ac me kitna
#       3     mode = pclass_groups(i)["Embarked"].fillna(mode)
#       4
#       5
#
# File c:\Users\manis\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\groupby\groupby.py:1115, in GroupBy.__getattr__(self, attr)
#    1112 if attr in self.obj:
#    1113     return self[attr]
# -> 1115 raise AttributeError(
#    1116     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1117 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'

# %% [markdown]
# ### `Q-3:` Make groups based on `"Embarked"` column. And for each of this embarked group, make another group based on `"Pclass"` and find out the average fare (round off up to 2 decimal places) for each "Pclass" for each group of "Embarked".
#
# **Sample Output:**
#
# ```bash
# {'C': {1: 105, 2: 25, 3: 11},
#  'Q': {1: 90, 2: 12, 3: 11},
#  'S': {1: 70, 2: 20, 3: 15}}
# ```

# %%
# code here

# %% [markdown]
# ## **Questions Based on Fifa Worldcup - 2022 Dataset:**
#
# You can read the dataset by using the below sample code
#
# ```python
# import pandas as pd
#
# fifa_df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vT3D_x_4DS6d51LKJ7ze1sxT5WpV5uiSVOFYHLwBiGru6vFyVv5h5-83AwFjxWYiWfCDjDAaarHAV-k/pub?gid=0&single=true&output=csv")
# ```

# %%
import pandas as pd

fifa = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vT3D_x_4DS6d51LKJ7ze1sxT5WpV5uiSVOFYHLwBiGru6vFyVv5h5-83AwFjxWYiWfCDjDAaarHAV-k/pub?gid=0&single=true&output=csv")

# %%
fifa
# Out:
#      Sl. No  Match No.       Team      Against Group  Goal  Possession (%)  \
# 0         1          1      Qatar      Ecuador     A     0              40
# 1         2          1    Ecuador        Qatar     A     2              46
# 2         3          2    England         Iran     B     6              69
# 3         4          2       Iran      England     B     2              20
# 4         5          3    Senegal  Netherlands     A     0              39
# ..      ...        ...        ...          ...   ...   ...             ...
# 123     124         62    Morocco         Fram     F     0              55
# 124     125         63    Croatia      Morocco     F     2              45
# 125     126         63    Morocco      Croatia     F     1              45
# 126     127         64  Argentina       France     C     3              46
# 127     128         64     France    Argentina     D     3              40
#
#      Inside Penalty Area  Outside Penalty Area  Assists  ...  Fouls Against  \
# 0                      0                     0        0  ...             15
# 1                      2                     0        1  ...             15
# 2                      6                     0        6  ...              9
# 3                      2                     0        1  ...             14
# 4                      0                     0        0  ...             13
# ..                   ...                   ...      ...  ...            ...
# 123                    0                     0        0  ...             11
# 124                    2                     0        2  ...             13
# 125                    1                     0        0  ...             11
# 126                    3                     0        1  ...             26
# 127                    3                     0        1  ...             19
#
#      Offsides  Passes  Passes Completed  Crosses  Crosses Completed  Corners  \
# 0           3     453               387       10                  5        1
# 1           4     484               419       26                 10        3
# 2           2     810               733       29                  9        8
# 3           2     232               156       11                  3        0
# 4           2     391               326       22                  8        6
# ..        ...     ...               ...      ...                ...      ...
# 123         3     583               518       22                  1        3
# 124         2     491               430       21                  3        6
# 125         2     494               428       20                  5        3
# 126         4     648               544       20                  4        6
# 127         4     516               419       24                  3        5
#
#      Free Kicks  Penalties Scored  Pts
# 0            19                 0    0
# 1            17                 1    3
# 2            16                 0    3
# 3            10                 1    0
# 4            14                 0    0
# ..          ...               ...  ...
# 123          15                 0    0
# 124          13                 0    3
# 125          15                 0    0
# 126          22                 5    3
# 127          28                 4    0
#
# [128 rows x 38 columns]

# %% [markdown]
# ### `Q-4:` Perform `groupby` based on the `"Team"` column and then perform Z Normalization on top of the below columns of each group:
# 1. Passes
# 2. Passes Completed
# 3. Attempted Line Breaks
# 4. Completed Line Breaks
#
# You have to make a python function named `z_normalization` which takes two arguments:
#
# 1. *group:* Every group that you have created
# 2. *cols_to_perform:* This parameter takes a list of columns on which you have to perform the Z-Normalization.
#
# For this problem, you have to use th `apply()` method.
#
# $\Large Z \ - \ Normalization = \frac{X_i - \mu}{std} $
#
# After that find out the below values for each group:
# - minimum "Passess"
# - maximum "Passess"
# - minimum "Yellow Cards"
# - maximum "Yellow cards"
# - average "Yellow Cards"
# - maximum "Attempted Line Breaks"
# - minimum "Attempted Line Breaks"
# - standardard deviation of "Attempted Line Breaks"
# - average Possession

# %%
# code here
team_groupby= fifa.groupby("Team").sum()
team_groupby
# Out:
#                 Sl. No  Match No.  \
# Team
# Argentina          597        301
# Australia          231        116
# Belgium            156         79
# Brazil             409        206
# Cameroon           178         90
# Canada             161         81
# Costa Rica         159         80
# Croatia            618        311
# Denmark            131         66
# Ecuador            107         54
# England            334        169
# France             608        306
# Germany            163         82
# Ghana              179         90
# Iran               109         55
# Japan              259        131
# Korea Republic     286        144
# Mexico             141         71
# Morocco            629        316
# Netherlands        320        162
# Poland             236        119
# Portugal           413        208
# Qatar              102         52
# Saudi Arabia       133         67
# Senegal            213        107
# Serbia             183         92
# Spain              272        137
# Switzerland        293        147
# Tunisia            128         65
# United States      217        109
# Uruguay            181         91
# Wales              110         56
#
#                                                           Against    Group  \
# Team
# Argentina       Saudi ArabiaMexicoPolandAustraliaNetherlandsCr...  CCCCCCC
# Australia                           FranceTunisiaDenmarkArgentina     DDDD
# Belgium                                      CanadaMoroccoCroatia      FFF
# Brazil             SerbiaSwitzerlandCameroonKorea RepublicCroatia    GGGGG
# Cameroon                                  SwitzerlandSerbiaBrazil      GGG
# Canada                                      BelgiumCroatiaMorocco      FFF
# Costa Rica                                      SpainJapanGermany      EEE
# Croatia           MoroccoCanadaBelgiumJapanBrazilArgentinaMorocco  FFFFFFF
# Denmark                                    TunisiaFranceAustralia      DDD
# Ecuador                                   QatarNetherlandsSenegal      AAA
# England                       IranUnited StatesWalesSenegalFrance    BBBBB
# France          AustraliaDenmarkTunisiaPolandEnglandMoroccoArg...  DDDDDDD
# Germany                                      JapanSpainCosta Rica      EEE
# Ghana                               PortugalKorea RepublicUruguay      HHH
# Iran                                    EnglandWalesUnited States      BBB
# Japan                               GermanyCosta RicaSpainCroatia     EEEE
# Korea Republic                         UruguayGhanaPortugalBrazil     HHHH
# Mexico                                PolandArgentinaSaudi Arabia      CCC
# Morocco              CroatiaBelgiumCanadaSpainPortugalFramCroatia  FFFFFFF
# Netherlands             SenegalEcuadorQatarUnited StatesArgentina    AAAAA
# Poland                          MexicoSaudi ArabiaArgentinaFrance     CCCC
# Portugal             GhanaUruguayKorea RepublicSwitzerlandMorocco    HHHHH
# Qatar                                   EcuadorSenegalNetherlands      AAA
# Saudi Arabia                                ArgentinaPolandMexico      CCC
# Senegal                            NetherlandsQatarEcuadorEngland     AAAA
# Serbia                                  BrazilCameroonSwitzerland      GGG
# Spain                               Costa RicaGermanyJapanMorocco     EEEE
# Switzerland                          CameroonBrazilSerbiaPortugal     GGGG
# Tunisia                                    DenmarkAustraliaFrance      DDD
# United States                         WalesEnglandIranNetherlands     BBBB
# Uruguay                               Korea RepublicPortugalGhana      HHH
# Wales                                    United StatesIranEngland      BBB
#
#                 Goal  Possession (%)  Inside Penalty Area  \
# Team
# Argentina         15             345                   13
# Australia          4             125                    3
# Belgium            1             147                    1
# Brazil             8             252                    8
# Cameroon           4             115                    4
# Canada             2             133                    1
# Costa Rica         3              82                    2
# Croatia            8             332                    7
# Denmark            1             154                    1
# Ecuador            4             128                    4
# England           13             286                   12
# France            16             314                   15
# Germany            6             159                    6
# Ghana              5             111                    5
# Iran               4              95                    3
# Japan              5             121                    4
# Korea Republic     5             169                    4
# Mexico             2             140                    1
# Morocco            6             240                    4
# Netherlands       10             220                    9
# Poland             3             128                    3
# Portugal          12             269                   11
# Qatar              1             118                    1
# Saudi Arabia       3             110                    3
# Senegal            5             154                    5
# Serbia             5             128                    4
# Spain              9             268                    9
# Switzerland        5             172                    5
# Tunisia            1             116                    0
# United States      3             188                    3
# Uruguay            2             123                    2
# Wales              1             123                    1
#
#                 Outside Penalty Area  Assists  Total Attempts  ...  \
# Team                                                           ...
# Argentina                          2        8             104  ...
# Australia                          0        3              25  ...
# Belgium                            0        1              34  ...
# Brazil                             0        6              90  ...
# Cameroon                           0        4              27  ...
# Canada                             0        1              34  ...
# Costa Rica                         0        1              11  ...
# Croatia                            1        8              83  ...
# Denmark                            0        1              36  ...
# Ecuador                            0        2              27  ...
# England                            1       11              60  ...
# France                             1       12             101  ...
# Germany                            0        5              67  ...
# Ghana                              0        2              25  ...
# Iran                               1        2              35  ...
# Japan                              1        4              43  ...
# Korea Republic                     1        2              49  ...
# Mexico                             1        1              43  ...
# Morocco                            2        3              60  ...
# Netherlands                        1        8              41  ...
# Poland                             0        1              32  ...
# Portugal                           1        8              62  ...
# Qatar                              0        1              21  ...
# Saudi Arabia                       0        2              29  ...
# Senegal                            0        2              52  ...
# Serbia                             1        4              31  ...
# Spain                              0        5              52  ...
# Switzerland                        0        4              36  ...
# Tunisia                            1        1              30  ...
# United States                      0        3              45  ...
# Uruguay                            0        1              32  ...
# Wales                              0        0              24  ...
#
#                 Fouls Against  Offsides  Passes  Passes Completed  Crosses  \
# Team
# Argentina                 100        23    4358              3837      122
# Australia                  52         1    1536              1206       58
# Belgium                    30         3    1821              1613       59
# Brazil                     63         8    3009              2696      116
# Cameroon                   32         2    1159               934       52
# Canada                     33         8    1498              1298       61
# Costa Rica                 24        13    1032               811       26
# Croatia                    90        11    4274              3756      198
# Denmark                    28         5    1789              1572       84
# Ecuador                    50         8    1361              1141       72
# England                    53         5    3053              2726      100
# France                     69        16    3656              3192      146
# Germany                    26        12    1906              1695       83
# Ghana                      46         4    1179               980       45
# Iran                       37         6     990               737       55
# Japan                      58         9    1640              1333       67
# Korea Republic             45         7    1866              1607       92
# Mexico                     51        13    1268              1049       84
# Morocco                    97        19    2729              2253       92
# Netherlands                73         8    2827              2466       89
# Poland                     48         1    1420              1132       54
# Portugal                   56        13    2971              2617      105
# Qatar                      22         7    1334              1134       46
# Saudi Arabia               56         3    1124               885       45
# Senegal                    48         8    1572              1291       76
# Serbia                     43         4    1392              1164       59
# Spain                      41        11    3823              3526       84
# Switzerland                52         6    1900              1612       67
# Tunisia                    40         7    1235               986       65
# United States              45         5    2038              1789      109
# Uruguay                    34         3    1364              1126       49
# Wales                      35         4    1242               995       39
#
#                 Crosses Completed  Corners  Free Kicks  Penalties Scored  Pts
# Team
# Argentina                      33       39         122                12   18
# Australia                      10        8          48                 0    6
# Belgium                        17       17          43                 0    4
# Brazil                         24       37          85                 3    9
# Cameroon                        8       12          46                 0    4
# Canada                         17       12          42                 0    0
# Costa Rica                      6        1          45                 0    3
# Croatia                        55       30         106                 7   14
# Denmark                        24       21          28                 0    1
# Ecuador                        24       11          47                 1    4
# England                        32       25          74                 1   10
# France                         49       38          98                 4   15
# Germany                        22       25          39                 1    4
# Ghana                           7       13          41                 0    3
# Iran                           10        8          32                 1    3
# Japan                          17       19          45                 1    6
# Korea Republic                 23       24          41                 0    4
# Mexico                         16       16          55                 0    4
# Morocco                        20       12         102                 3   13
# Netherlands                    20       19          68                 3   10
# Poland                         19       11          54                 1    4
# Portugal                       28       28          74                 2    9
# Qatar                          14        9          58                 0    0
# Saudi Arabia                   10        8          57                 0    3
# Senegal                        24       22          63                 1    6
# Serbia                         13        9          30                 0    1
# Spain                          16       21          65                 1    4
# Switzerland                    14       20          57                 0    6
# Tunisia                        13       21          33                 0    4
# United States                  17       22          46                 0    5
# Uruguay                        13        8          43                 0    4
# Wales                          12        6          37                 1    2
#
# [32 rows x 37 columns]

# %%
fifa.columns.tolist()
# Out:
# ['Sl. No',
#  'Match No.',
#  'Team',
#  'Against',
#  'Group',
#  'Goal',
#  'Possession (%)',
#  'Inside Penalty Area',
#  'Outside Penalty Area',
#  'Assists',
#  'Total Attempts',
#  'On Target',
#  'Off Target',
#  'Target in Penalty',
#  'Target from Outside',
#  'Left Channel',
#  'Left Inside Channel',
#  'Central Channel',
#  'Right Inside Channel',
#  'Right Channel',
#  'Receptions MD',
#  'Receptions D',
#  'Attempted Line Breaks',
#  'Completed Line Breaks',
#  'Attempted Defensive Line Breaks',
#  'Completed Defensive Line Breaks',
#  'Yellow Cards',
#  'Red Cards',
#  'Fouls Against',
#  'Offsides',
#  'Passes',
#  'Passes Completed',
#  'Crosses',
#  'Crosses Completed',
#  'Corners',
#  'Free Kicks',
#  'Penalties Scored',
#  'Pts']

# %%
# code here
def z_normalization(group, cols_to_perform):
    for col in cols_to_perform:
        std = group[col].std()
        mean = group[col].mean()
        group[f"{col}_z_norm"] = (group[col] - mean)/std
    return group


cols_to_perform = ["Passes", "Passes Completed", "Attempted Line Breaks", "Completed Line Breaks"]
groups = fifa.groupby("Team")
groups = groups.apply(z_normalization, cols_to_perform = cols_to_perform).groupby("Team")
groups.agg(
{
    "Passes": ["min", "max"],
    "Yellow Cards": ["min", "max", "mean"],
    "Attempted Line Breaks": ["max", "min", "std"],
    "Possession (%)": "mean"
})
# Out:
#                Passes       Yellow Cards               Attempted Line Breaks  \
#                   min   max          min max      mean                   max
# Team
# Argentina         408   862            0   8  2.285714                   249
# Australia         286   466            0   3  1.750000                   171
# Belgium           512   685            1   3  1.666667                   195
# Brazil            548   695            0   3  1.200000                   193
# Cameroon          295   500            1   5  2.666667                   182
# Canada            448   536            2   4  2.666667                   176
# Costa Rica        231   454            1   3  2.000000                   154
# Croatia           461   724            0   2  1.142857                   259
# Denmark           537   650            1   2  1.666667                   241
# Ecuador           429   484            0   2  1.000000                   177
# England           508   810            0   1  0.200000                   208
# France            358   734            0   3  1.142857                   179
# Germany           352   827            0   3  1.000000                   256
# Ghana             319   460            2   4  2.666667                   188
# Iran              232   463            2   3  2.333333                   195
# Japan             225   591            0   3  1.500000                   253
# Korea Republic    359   548            1   2  1.500000                   201
# Mexico            356   500            1   4  2.333333                   198
# Morocco           229   583            0   3  1.285714                   157
# Netherlands       403   786            0   4  1.800000                   198
# Poland            303   466            1   3  1.750000                   156
# Portugal          461   678            0   3  1.200000                   197
# Qatar             424   457            0   4  2.333333                   174
# Saudi Arabia      267   560            2   6  4.666667                   205
# Senegal           277   511            1   3  1.750000                   184
# Serbia            403   513            2   7  4.000000                   184
# Spain             647  1070            0   1  0.500000                   237
# Switzerland       403   512            1   4  2.250000                   178
# Tunisia           328   501            1   3  1.666667                   200
# United States     427   572            0   4  1.250000                   204
# Uruguay           390   528            1   3  2.000000                   186
# Wales             325   508            1   2  1.666667                   208
#
#                                Possession (%)
#                 min        std           mean
# Team
# Argentina       141  38.774685      49.285714
# Australia       133  17.682383      31.250000
# Belgium         167  14.422205      49.000000
# Brazil          164  10.691118      50.400000
# Cameroon        144  19.857828      38.333333
# Canada          102  37.753587      44.333333
# Costa Rica       86  38.974351      27.333333
# Croatia          97  54.499891      47.428571
# Denmark         173  34.000000      51.333333
# Ecuador         143  17.009801      42.666667
# England         133  29.676590      57.200000
# France          126  21.407609      44.857143
# Germany         143  56.624494      53.000000
# Ghana           122  33.020196      37.000000
# Iran             56  77.526340      31.666667
# Japan           104  64.048810      30.250000
# Korea Republic  139  27.072434      42.250000
# Mexico          127  40.706265      46.666667
# Morocco         128  10.641339      34.285714
# Netherlands     168  12.759310      44.000000
# Poland           79  36.326070      32.000000
# Portugal        165  13.049904      53.800000
# Qatar           159   7.767453      39.333333
# Saudi Arabia    147  29.022979      36.666667
# Senegal         143  16.938615      38.500000
# Serbia          140  22.188586      42.666667
# Spain           186  24.289916      67.000000
# Switzerland     157   9.032349      43.000000
# Tunisia         153  24.419937      38.666667
# United States   143  27.693260      47.000000
# Uruguay         146  22.030282      41.000000
# Wales           104  53.028294      41.000000

# %% [markdown]
# ## **Questions on IPL wala dataset**
#
# ball by ball dataset - https://drive.google.com/file/d/1-kvv_9KCSAFWcrhS9WgTxSrURkRh6GNt/view?usp=share_link

# %% [markdown]
# ###`Q-5:` Find batsman in below category-
# * Highest score while chasing
# * Best Strike rate while chasing and have faced 100+ balls
#
#
# > Chasing mean team batting in second inning

# %%
# code here

# %% [markdown]
# ###`Q-6` Most Successful bowler against any batsman. Find that pair of bowler and batsman.
# > Most Successful in terms of dissmissal. A bowler who have dissmissed any batsman most no of times. If any two pairs have same no of dissmisal, consider runs conceded by bowler to that batsman. Those who have concede lesser runs is more successful.

# %%
# code here

# %% [markdown]
# ###`Q-7`: Most successful batting pair in IPL. Batting pair who have scored most runs playing together.

# %%
# code here

# %% [markdown]
# ###`Q-8:` Make a dataframe for all batting pairs played together.
# ```
# Batsman1 Batsman2 Runs Avg StrikeRate
# ```
#
# > Just to ease this question you can count wide-balls for strike rate.

# %%
# code here
