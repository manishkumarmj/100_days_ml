# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###`Q-1:` Write a program to create an empty series.

# %%
# code here
lst_empty = []
lst= pd.Series(lst_empty)
print(lst.astype('int')) # now its converted to lst of int empty
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ###`Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
lst1= pd.Series( [23, 56, 12, 89, 34, 67, 45, 78, 90, 11]).astype('int')
lst2= pd.Series( [7, 45, 23, 67, 12, 89, 56, 34, 78, 90]).astype('int')
lst3plus = pd.Series(lst1+lst2)
lst3sub = pd.Series(lst1-lst2)
lst3mul= pd.Series(lst1*lst2)
lst3div = pd.Series(lst1/lst2)

print(lst3plus)
print(lst3sub)
print(lst3mul)
print(lst3div)
# Out:
# 0     30
# 1    101
# 2     35
# 3    156
# 4     46
# 5    156
# 6    101
# 7    112
# 8    168
# 9    101
# dtype: int64
# 0    16
# 1    11
# 2   -11
# 3    22
# 4    22
# 5   -22
# 6   -11
# 7    44
# 8    12
# 9   -79
# dtype: int64
# 0     161
# 1    2520
# 2     276
# 3    5963
# 4     408
# 5    5963
# 6    2520
# 7    2652
# 8    7020
# 9     990
# dtype: int64
# 0    3.285714
# 1    1.244444
# 2    0.521739
# 3    1.328358
# 4    2.833333
# 5    0.752809
# 6    0.803571
# 7    2.294118
# 8    1.153846
# 9    0.122222
# dtype: float64

# %% [markdown]
# ###`Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
# code here
lst1= pd.Series( [23, 56, 12, 89, 34, 67, 45, 78, 90, 11]).astype('int')
lst2= pd.Series( [7, 45, 23, 67, 12, 89, 56, 34, 78, 90]).astype('int')
lst3 = pd.Series(lst1>lst2)
lst4 =pd.Series(lst1<lst2)
lst5=pd.Series(lst1==lst2)

# %% [markdown]
# ###`Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
def change_data(series ):
    return pd.to_numeric(series, errors="coerce" ) # coerce -> unable to convet = NaN value  
series = pd.Series([1,2,'Python', 2.0, True, 100])
change_data(series)
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float64

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %% [markdown]
# ###`Q-6` Find top 10 most run getter from the series.

# %%
# code here
ipl = pd.read_csv("batsman_runs_series.csv")
data=ipl.sort_values("batsman_run", ascending= False).head(10) 
data
# Out:
#              batter  batsman_run
# 569         V Kohli         6634
# 462        S Dhawan         6244
# 130       DA Warner         5883
# 430       RG Sharma         5881
# 493        SK Raina         5536
# 27   AB de Villiers         5181
# 108        CH Gayle         4997
# 339        MS Dhoni         4978
# 452      RV Uthappa         4954
# 256      KD Karthik         4377

# %% [markdown]
# ###`Q-7` No of players having runs above 3000

# %%
# code here
ipl[ipl['batsman_run']>3000]
# Out:
#              batter  batsman_run
# 27   AB de Villiers         5181
# 46        AM Rahane         4074
# 60        AT Rayudu         4190
# 108        CH Gayle         4997
# 130       DA Warner         5883
# 169    F du Plessis         3403
# 174       G Gambhir         4217
# 251      KA Pollard         3437
# 256      KD Karthik         4377
# 263        KL Rahul         3895
# 328       MK Pandey         3657
# 339        MS Dhoni         4978
# 430       RG Sharma         5881
# 452      RV Uthappa         4954
# 462        S Dhawan         6244
# 493        SK Raina         5536
# 511       SR Watson         3880
# 519       SV Samson         3526
# 569         V Kohli         6634
# 597       YK Pathan         3222

# %% [markdown]
# ###`Q-8` No of players having runs above mean value?

# %%
ipl[ipl['batsman_run']>ipl['batsman_run'].mean()]
# Out:
#               batter  batsman_run
# 15         A Symonds          974
# 27    AB de Villiers         5181
# 29      AC Gilchrist         2069
# 34        AD Mathews          724
# 36        AD Russell         2039
# ..               ...          ...
# 587          WP Saha         2427
# 594  Y Venugopal Rao          985
# 596      YBK Jaiswal          547
# 597        YK Pathan         3222
# 603     Yuvraj Singh         2754
#
# [128 rows x 2 columns]

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %% [markdown]
# ###`Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     ii. Item price is given in $, so convert it to rupees without currency symbol.
#     iii. Make data type of newly made series as float.
#     iv. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
items = pd.read_csv('items.csv')
items = pd.read_csv("items.csv", index_col = ['item_name'])
items.sample(8)


items["item_price"]=items["item_price"].str[1:].astype("float64")
items["item_price"].dtype
items["item_price"]=items["item_price"].fillna(items["item_price"].mean())
items["item_price"]= round(items["item_price"]*80,2)
items["item_price"]
# Out:
# item_name
# Chips and Fresh Tomato Salsa              191.2
# Izze                                      271.2
# Nantucket Nectar                          271.2
# Chips and Tomatillo-Green Chili Salsa     191.2
# Chicken Bowl                             1358.4
#                                           ...
# Steak Burrito                             940.0
# Steak Burrito                             940.0
# Chicken Salad Bowl                        900.0
# Chicken Salad Bowl                        700.0
# Chicken Salad Bowl                        700.0
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# ###`Q-10`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
items
# Out:
#                                        item_price
# item_name
# Chips and Fresh Tomato Salsa                191.2
# Izze                                        271.2
# Nantucket Nectar                            271.2
# Chips and Tomatillo-Green Chili Salsa       191.2
# Chicken Bowl                               1358.4
# ...                                           ...
# Steak Burrito                               940.0
# Steak Burrito                               940.0
# Chicken Salad Bowl                          900.0
# Chicken Salad Bowl                          700.0
# Chicken Salad Bowl                          700.0
#
# [4622 rows x 1 columns]

# %%
# code here
#1
items.mean()
# Out:
# item_price    597.042492
# dtype: float64

# %%
#2
items.quantile(q=0.3)
items.quantile(q=0.06)
# Out:
# item_price    100.0
# Name: 0.06, dtype: float64

# %%
#3
items.plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
items[(items>1000) & (items<2000)]
# Out:
#                                        item_price
# item_name
# Chips and Fresh Tomato Salsa                  NaN
# Izze                                          NaN
# Nantucket Nectar                              NaN
# Chips and Tomatillo-Green Chili Salsa         NaN
# Chicken Bowl                               1358.4
# ...                                           ...
# Steak Burrito                                 NaN
# Steak Burrito                                 NaN
# Chicken Salad Bowl                            NaN
# Chicken Salad Bowl                            NaN
# Chicken Salad Bowl                            NaN
#
# [4622 rows x 1 columns]
