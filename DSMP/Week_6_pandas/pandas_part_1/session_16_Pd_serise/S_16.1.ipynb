# %%
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
import numpy as np
import pandas as pd

# %%
subs = pd.read_csv('subs.csv',)
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
vk = pd.read_csv('kohli_ipl.csv', index_col='match_no')

# %%
movies = pd.read_csv('bollywood.csv',index_col='movie',)
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
# astype
import sys
sys.getsizeof(vk)
# Out:
# 3472

# %% [markdown]
#  - astype change data type and
#  - reduces the memory space

# %%
sys.getsizeof(vk.astype('int16'))
# Out:
# 2182

# %% [markdown]
# ## between
#  - 1 give your set of data of your range
#  -

# %%
vk_between = vk[vk['runs'].between(51, 99)]
vk_between
# Out:
#           runs
# match_no
# 34          58
# 41          71
# 44          56
# 45          67
# 52          70
# 57          57
# 68          73
# 71          51
# 73          58
# 74          65
# 80          57
# 81          93
# 82          99
# 85          56
# 97          67
# 99          73
# 103         51
# 104         62
# 110         82
# 116         75
# 117         79
# 119         80
# 122         52
# 127         75
# 129         54
# 131         54
# 132         62
# 134         64
# 137         55
# 141         58
# 144         57
# 145         92
# 148         68
# 152         70
# 160         84
# 162         67
# 175         72
# 178         90
# 188         72
# 197         51
# 198         53
# 209         58
# 213         73

# %% [markdown]
# # clip
#  - set value withing the range 100-200
#  - 50 -->100
#  - 269-->200

# %%
# clip
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs.clip(100,200)
# Out:
#      Subscribers gained
# 0                   100
# 1                   100
# 2                   100
# 3                   100
# 4                   100
# ..                  ...
# 360                 200
# 361                 200
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %% [markdown]
# # drop_duplicates
# - delete as u like -- 1st or last

# %%
# drop_duplicates
temp = pd.Series([1,1,2,2,3,3,4,4])
temp
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# 6    4
# 7    4
# dtype: int64

# %%
temp.drop_duplicates(keep='last')
# Out:
# 1    1
# 3    2
# 5    3
# 7    4
# dtype: int64

# %%
temp.duplicated().sum()
# Out:
# np.int64(4)

# %%
vk.duplicated().sum()
# Out:
# np.int64(137)

# %%
movies.drop_duplicates()
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Sssshhh...                            Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                Tanuja
# Right Here Right Now (film)                      Ankit
# Talaash: The Hunt Begins...              Rakhee Gulzar
# The Pink Mirror                        Edwin Fernandes
#
# [566 rows x 1 columns]

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.size
# Out:
# 10

# %%
temp.count()
# Out:
# np.int64(7)

# %%
# isnull
temp.isnull().sum()
# Out:
# np.int64(3)

# %%
# dropna
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna
temp.fillna(temp.mean())
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
# isin
vk[(vk == 49) | (vk == 99)]
# Out:
#           runs
# match_no
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# ...        ...
# 211        NaN
# 212        NaN
# 213        NaN
# 214        NaN
# 215        NaN
#
# [215 rows x 1 columns]

# %%
vk[vk.isin([49,99])]
# Out:
#           runs
# match_no
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# ...        ...
# 211        NaN
# 212        NaN
# 213        NaN
# 214        NaN
# 215        NaN
#
# [215 rows x 1 columns]

# %%
# apply
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
movies.apply(lambda x:x.split()[0].upper())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21596\641763083.py in ?()
# ----> 1 movies.apply(lambda x:x.split()[0].upper())
#
# c:\Users\manis\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10370             engine_kwargs=engine_kwargs,
#   10371             args=args,
#   10372             kwargs=kwargs,
#   10373         )
# > 10374         return op.apply().__finalize__(self, method="apply")
#
# c:\Users\manis\anaconda3\Lib\site-packages\pandas\core\apply.py in ?(self)
#     912         # raw
#     913         elif self.raw:
#     914             return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
#     915
# --> 916         return self.apply_standard()
#
# ...

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.apply(lambda x:'good day' if x > subs.mean() else 'bad day')
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
subs.mean()
# Out:
# 135.64383561643837

# %%
# copy

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
new = vk.head()

# %%
new
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
new[1] = 1

# %%
new = vk.head().copy()

# %%
new[1] = 100

# %%
new
# Out:
# match_no
# 1    100
# 2     23
# 3     13
# 4     12
# 5      1
# Name: runs, dtype: int64

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64
