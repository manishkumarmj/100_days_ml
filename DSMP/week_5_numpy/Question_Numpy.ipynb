# %% [markdown]
# * https://www.youtube.com/@KeithGalli
# * Q-> 100  https://www.youtube.com/watch?v=PM504XhEVCU
# * some interesting stuff https://www.youtube.com/watch?v=D0GG8ABxoDE&list=PLeRUz657THGj7gYxY6dDdldL2TrV5dRk6

# %% [markdown]
# # intermediate level
# https://learn.microsoft.com/en-us/shows/even-more-python-for-beginners-data-tools/working-with-numpy--even-more-python-for-beginners-data-tools-27-of-31
