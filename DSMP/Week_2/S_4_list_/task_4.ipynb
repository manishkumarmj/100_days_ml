# %% [markdown]
# ###`Problem 1:` Combine two lists index-wise(columns wise)
#
# Write a program to add two lists index-wise. Create a new list that contains the 0th index item from both the list, then the 1st index item, and so on till the last element. any leftover items will get added at the end of the new list.
#
# `Given List:`
# ```
# list1 = ["M", "na", "i", "Kh"]
# list2 = ["y", "me", "s", "an"]
# ```
#
# `Output:`
# ```
# [['M','y'], ['na', me'], ['i', 's'], ['Kh', 'an']]
# ```

# %%
# Write code here
list1 = ["M", "na", "i", "Kh"]
list2 = ["y", "me", "s", "an"]

final_list =[]

for i in range(len(list1)):
    final_list.append(
        [[list1[i],
           list2[i]]]
        )
print(final_list)
# Out:
# [[['M', 'y']], [['na', 'me']], [['i', 's']], [['Kh', 'an']]]

# %% [markdown]
# ### `Problem 2:` Add new item to list after a specified item
# Write a program to add item 7000 after 6000 in the following Python List
# ```
# list1 =
# ```[10, 20, [300, 400, [5000, 6000], 500], 30, 40]
# `Output:`
# ```
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]
# ```

# %%
# Write code here
list1=[10, 20, [300, 400, [5000, 6000], 500], 30, 40]
print(list1[2][0])
print(list1[2][1])
print(list1[2][2])
print(list1[2][2][0])
print(list1[2][2][1])
list1[2][2].append(7000) # no need to add 3 rd place 
print(list1[2][2][2])
# Out:
# 300
# 400
# [5000, 6000]
# 5000
# 6000
# 7000

# %% [markdown]
# ###`Problem 3:` Update no of items available
#
# Suppose you are given a list of candy and another list of same size representing no of items of respective candy.
#
# i.e -
# ```
# candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
# no_of_items = [10,20,34,74,32]
# ```
#
# Write a program to show no. of items of each candy type.
#
# `Output:`
#
# ```
# Jelly Belly-10
# Kit Kat-20
# Double Bubble-34
# Milky Way-74
# Three Musketeers-32
#
# ```

# %%
# Write code here

candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
no_of_items = [10,20,34,74,32]

box_list = []
for list2 in range(len(candy_list)):
    box_list.append(  
        [candy_list[list2],no_of_items[list2]]
    )
#print(box_list)
#print(box_list[0])
#print(box_list[0][1])

for row in range(len(box_list)):
    for col in  range(len(box_list[row])):
        print(box_list[row][col],end="-")
    print()
# Out:
# Jelly Belly-10-
# Kit Kat-20-
# Double Bubble-34-
# Milky Way-74-
# Three Musketeers-32-

# %%
for row in range(len(box_list)):
    for col in range(len(box_list[row])):
        if col == len(box_list[row]) - 1:
            print(box_list[row][col])  # Last element: no hyphen
        else:
            print(box_list[row][col], end="-")
# Out:
# Jelly Belly-10
# Kit Kat-20
# Double Bubble-34
# Milky Way-74
# Three Musketeers-32

# %% [markdown]
# ###`Problem 4:` Running Sum on list
# Write a program to print a list after performing running sum on it.
#
# i.e:
#
# `Input:`
# ```
# list1 = [1,2,3,4,5,6]
# ```
# `Output:`
# ```
# [1,3,6,10,15,21]
# ```

# %%
# Write code here
list1 = [1,2,3,4,5,6]
sum =0
cout = []
for i in (list1):
    sum +=i 
    cout.append(sum)
print(cout)
# Out:
# [1, 3, 6, 10, 15, 21]

# %% [markdown]
# ###`Problem 5:` You are given a list of integers. You are asked to make a list by running through elements of the list by adding all elements greater and itself.
#
# i.e. Say given list is `[2,4,6,10,1]`
# resultant list will be `[22,20,10,23]`.
#
# For 1st element `2` ->> these are greater `(4+6+10)` values and `2` itself so on adding becomes `22`.
#
# For 2nd element `4` ->> greater elements are `(6, 10)` and `4` itself, so on adding `20`
#
# like wise for all other elememts.
#
# `[2,4,6,10,1]`-->`[22,20,16,10,23]`

# %%
# Write code here
list = [2,4,6,10,1]
list_sum = []
sum =0
for i in range(len(list)):
    for search in range(len(list)):
        if list[i] < list[search] and list[i] != list[search]:
            sum += list[search]
    list_sum.append((sum+list[i]))    
    sum = 0
    search =0
print(list_sum)
# Out:
# [22, 20, 16, 10, 23]

# %% [markdown]
# ###`Problem 6:` Find list of common unique items from two list. and show in increasing order
#
# `Input`
#
# ```
# num1 = [23,45,67,78,89,34]
# num2 = [34,89,55,56,39,67]
# ```
#
# `Output:`
# ```
# [34, 67, 89]
# ```

# %%
# Write code here
num1 = [23,45,67,78,89,34]
num2 = [34,89,55,56,39,67]
num1=sorted(num1)
num2=sorted(num2)
print(num1)
print(num2)
common_nums = []

for i in range(len(num1)):
    for j in range(len(num1)):
        if num1[i]== num2[j]:
            common_nums.append(num1[i])
    j = 0 
print(common_nums)
# Out:
# [23, 34, 45, 67, 78, 89]
# [34, 39, 55, 56, 67, 89]
# [34, 67, 89]

# %% [markdown]
# ###`Problem 7:` Sort a list of alphanumeric strings based on product value of numeric character in it. If in any string there is no numeric character take it's product value as 1.
#
# `Input:`
# ```
# ['1ac21', '23fg', '456', '098d','1','kls']
# ```
#
# `Output:`
# ```
# ['456', '23fg', '1ac21', '1', 'kls', '098d']
#
# ```

# %%
# Write code here
Input=['1ac21', '23fg', '456', '098d','1','kls']

resul= [ ]
max = 0
sumdata = []
for listme in Input:
    sum =1
    for itemkeandar in listme:
        if itemkeandar.isdigit():
            sum = sum* int(itemkeandar)
        elif itemkeandar.isalpha():
            sum = sum
    finalsum = int(sum)
    if max < sum :
        max = sum 
        resul.insert(0,listme)
        sumdata.insert(0,int(sum))
    else:
        max = max 
        # 
        if sumdata and finalsum < int(sumdata[-1]): #  1 ,> 0 
            sumdata.append(sum)
            resul.append(listme)
        elif finalsum > sumdata[-1]: #   0 < 1
            resul.insert(-1,listme)
            sumdata.insert(-1,sum)


print(resul)
# Out:
# ['456', '23fg', '1ac21', '1', 'kls', '098d']

# %% [markdown]
# `Problem 8:` Split String of list on K character.
#
# **Example :**
#
# Input:
# ```bash
# ['CampusX is a channel', 'for data-science', 'aspirants.']
# ```
#
# Output:
# ```bash
# ['CampusX', 'is', 'a', 'channel', 'for', 'data-science', 'aspirants.']
# ```

# %% [markdown]
# ### extend() adds each element individually to the list
#
# ### append() adds whole list as one item
# arr = []
# arr.append([1,2])  # [[1,2]]
#
# ### extend() adds elements one by one
# arr = []
# arr.extend([1,2])  # [1,2]

# %%
# Write code here


Input =['CampusX is a channel', 'for data-science', 'aspirants.']
patchup = []
for i in Input:
    patchup.extend(i.split())
patchup
# Out:
# ['CampusX', 'is', 'a', 'channel', 'for', 'data-science', 'aspirants.']

# %% [markdown]
# ### `Problem 9:` Convert Character Matrix to single String using string comprehension.
#
# **Example 1:**
#
# Input:
# ```bash
# [['c', 'a', 'm', 'p', 'u', 'x'], ['i', 's'], ['b', 'e', 's', 't'], ['c', 'h', 'a', 'n', 'n', 'e', 'l']]
# ```
#
# Output:
# ```bash
# campux is best channel
# ```

# %%
# Write code here


input1= [['c', 'a', 'm', 'p', 'u', 'x'], ['i', 's'], ['b', 'e', 's', 't'], ['c', 'h', 'a', 'n', 'n', 'e', 'l']]

for bhar_wala_array in input1:
    for andarwala_array in bhar_wala_array:
        print(andarwala_array,end="")
    print(end= " ")
# Out:
# campux is best channel

# %% [markdown]
# ### `Problem 10:` Add Space between Potential Words.
#
# **Example:**
#
# Input:
#
# ```bash
# ['campusxIs', 'bestFor', 'dataScientist']
# ```
#
# Output:
# ```bash
# ['campusx Is', 'best For', 'data Scientist']
# ```

# %%
# Code here
list1 = ['campusxIs', 'bestFor', 'dataScientist']
result = []
for i in list1:
    temp = ""
    for andarwala in i :
        if andarwala.isupper() and temp: #temp = 0 ->false  
            # here temp has no  value so false 
            result.append(temp)
            temp = andarwala
        else:
            temp += andarwala
    result.append(temp)
print(result)
# Out:
# ['campusx', 'Is', 'best', 'For', 'data', 'Scientist']

# %% [markdown]
# ### `Problem 11:` Write a program that can perform union operation on 2 lists
#
# **Example:**
#
# Input:
#
# ```bash
# [1,2,3,4,5,1]
# [2,3,5,7,8]
# ```
#
# Output:
# ```bash
# [1,2,3,4,5,7,8]
# ```

# %%
# Write code here
list1=[1,2,3,4,5,1]
list2=[2,3,5,7,8]
list1= list1+list2
list1=sorted(list1)
result1=[]
for item in list1:
    if item not in result1:
        result1.append(item)


print(result1)
# Out:
# [1, 2, 3, 4, 5, 7, 8]

# %%
arr = [1, 2, 2, 3, 3, 4, 5, 5]

# Method 1: set() (loses order)
unique = list(set(arr))  # [1, 2, 3, 4, 5]
# Step 1: set(arr) removes duplicate

# Step 2: list() converts back to list5]

# %% [markdown]
# ### `Problem 12:` Write a program that can find the max number of each row of a matrix
#
# **Example:**
#
# Input:
#
# ```bash
# [[1,2,3],[4,5,6],[7,8,9]]
# ```
#
# Output:
# ```bash
# [3,6,9]
# ```

# %%
# Write code here

# %% [markdown]
# ### `Problem 13:` Write a list comprehension to print the following matrix
#
# [[0, 1, 2], [3, 4, 5], [6, 7, 8]]

# %%
# Write code here

# %% [markdown]
# ### `Problem 14:` Write a list comprehension that can transpose a given matrix
#
# matrix = [<br>
#   [1,2,3],<br>
#           [4,5,6],<br>
#           [7,8,9]<br>]<br>
#
# [1, 4, 7]<br>
# [2, 5, 8]<br>
# [3, 6, 9]<br>

# %%
# Write code here

# %% [markdown]
# ### `Problem 15:` Write a list comprehension that can flatten a nested list
#
# Input<br>
# matrix = [<br>
#   [1,2,3],<br>
#           [4,5,6],<br>
#           [7,8,9]<br>]<br>
#
# Output:<br>
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# Write code here
