# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here
print("Data" ,"Science" ,"Mentorship", "Program",
"By" ,"CampusX", sep='-')
# Out:
# Data-Science-Mentorship-Program-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# Write your code here

a = 5
b = 6
temp = 0

print( 'a =',a,  "b = ",b ) 
temp = b 
b= a
a = temp
print( 'a =',a,  "b = ",b )
# Out:
# a = 5 b =  6
# a = 6 b =  5

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Write your code here
x1= 5 #int( input(" Enter the nuber x1"))
y1= 3 #int( input(" Enter the nuber y1"))
x2= 8 #int( input(" Enter the nuber x2"))
y2=  7#int( input(" Enter the nuber y2"))

euclidean_distance= ((x1-x2)**2 + (y1-y2)**2)**0.5
euclidean_distance
# Out:
# 5.0

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# Write your code here

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
heads = int(input("heads -> "))
legs = int(input("legs -> "))

# dogs + chickens = heads
# 4*dogs + 2*chickens = legs

chickens = (4*heads - legs) // 2
dogs = heads - chickens

print("dogs ->", dogs)
print("chicken ->", chickens)
# Out:
# dogs -> -2
# chicken -> 7

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Write your code here
nums =int(input("Enter the number"))
square = [count**2 for count in range( 1 , nums+1)]
print(square)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %% [markdown]
# - First term
# - Second term
# - N

# %%
# Write your code here
first_term  =  5 #int(input(" first term "))
Second_term =  8 #int(input(" first term "))
n = 3  #int(input(" nth term "))
differnce = Second_term- first_term
for i in range(n):
    arithmetic_Series = first_term + i*(differnce)
print(arithmetic_Series)
# Out:
# 11

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here
num1 = 2 
den1 = 3 

num2 = 3
den2 = 4

final_deno = den1*den2

final_num= (num1*den2) +(num2*den1)

fraction = final_num / final_deno
fraction
# Out:
# 1.4166666666666667
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
