# %%
import pandas as pd
import numpy as np

# %%
ipl = pd.read_csv('ipl-matches.csv')

# %% [markdown]
# # find all the final matches

# %%
ipl.sample(6)
# Out:
#           ID           City        Date   Season MatchNumber  \
# 811   419129      Ahmedabad  2010-03-28  2009/10          24
# 350  1082613        Kolkata  2017-04-21     2017          23
# 52   1304068         Mumbai  2022-04-12     2022          22
# 113  1254078      Ahmedabad  2021-04-26     2021          21
# 494   734045         Mumbai  2014-05-28     2014  Eliminator
# 478   829731  Visakhapatnam  2015-04-18     2015          13
#
#                      Team1                        Team2  \
# 811       Rajasthan Royals          Chennai Super Kings
# 350  Kolkata Knight Riders                Gujarat Lions
# 52     Chennai Super Kings  Royal Challengers Bangalore
# 113           Punjab Kings        Kolkata Knight Riders
# 494    Chennai Super Kings               Mumbai Indians
# 478    Sunrisers Hyderabad             Delhi Daredevils
#
#                                                  Venue  \
# 811                       Sardar Patel Stadium, Motera
# ...

# %%
mask=ipl['MatchNumber']=='Final'
new_final=ipl[mask]
new_final[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
new_final=new_final[['Season','WinningTeam']].count()

# %% [markdown]
# # is sum not working

# %%
new_final[['Season','WinningTeam']].count()
# Out:
# np.int64(2)

# %% [markdown]
# # How many super over

# %%
ipl.sample(8)
# Out:
#           ID         City        Date   Season MatchNumber  \
# 221  1178408    Hyderabad  2019-04-17     2019          33
# 208  1178421        Delhi  2019-04-28     2019          46
# 934   335997      Kolkata  2008-04-29  2007/08          16
# 272  1136602        Delhi  2018-05-10     2018          42
# 233  1178396       Jaipur  2019-04-07     2019          21
# 865   392209  East London  2009-05-04     2009          29
# 647   548362         Pune  2012-05-11     2012          57
# 391   980983    Hyderabad  2016-05-12     2016          42
#
#                      Team1                        Team2  \
# 221    Chennai Super Kings          Sunrisers Hyderabad
# 208         Delhi Capitals  Royal Challengers Bangalore
# 934  Kolkata Knight Riders               Mumbai Indians
# 272       Delhi Daredevils          Sunrisers Hyderabad
# 233       Rajasthan Royals        Kolkata Knight Riders
# 865    Chennai Super Kings              Deccan Chargers
# ...

# %%
mask=ipl['SuperOver']=='Y'
super_over_mask= ipl[mask]
super_over_mask.shape[0] # shape 0 will define
# Out:
# 14

# %% [markdown]
# # How many matches has csk won in kolkata

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %% [markdown]
# WonBy,Venue

# %% [markdown]
# # & amp% or bitwise or symbol
#  -  we are working with  bolean  value  1,0

# %%
mask = (ipl['City']=='Kolkata') & (ipl['WinningTeam']=='Chennai Super Kings')
ipl[mask].shape[0]
# Out:
# 5

# %% [markdown]
# # toss winner is match winner in percentage

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
mask = (ipl['TossWinner'] ==  (ipl['WinningTeam']))
outcome = ipl[mask].shape[0]
percentage = (outcome*100)/ipl.shape[0]
percentage
# Out:
# 51.473684210526315

# %% [markdown]
# # movies with rating higher than 8 and votes>10000

# %%
mov= pd.read_csv('movies.csv')

# %%
mov.sample(5)
# Out:
#                          title_x    imdb_id  \
# 817            The Dirty Picture  tt1954206
# 901   Tees Maar Khan (2010 film)  tt1572311
# 677                  Bittoo Boss  tt2347289
# 1628                    Humsafar  tt2403201
# 444       Chinar Daastaan-E-Ishq  tt5021968
#
#                                             poster_path  \
# 817   https://upload.wikimedia.org/wikipedia/en/thum...
# 901   https://upload.wikimedia.org/wikipedia/en/thum...
# 677   https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 444   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 817     https://en.wikipedia.org/wiki/The_Dirty_Picture
# 901   https://en.wikipedia.org/wiki/Tees_Maar_Khan_(...
# 677           https://en.wikipedia.org/wiki/Bittoo_Boss
# 1628             https://en.wikipedia.org/wiki/Humsafar
# 444   https://en.wikipedia.org/wiki/Chinar_Daastaan-...
#
# ...

# %% [markdown]
# imdb_rating
# imdb_votes

# %%
mov[(mov['imdb_rating']>8)&(mov['imdb_votes']>1000)]
# Out:
#                           title_x     imdb_id  \
# 0        Uri: The Surgical Strike   tt8291224
# 11                      Gully Boy   tt2395469
# 37              Article 15 (film)  tt10324144
# 40                Super 30 (film)   tt7485048
# 53                    Section 375   tt8144834
# 58              Ghost (2019 film)   tt9378950
# 59               Bala (2019 film)   tt9420648
# 62                 Saand Ki Aankh   tt8108206
# 64                    Ujda Chaman  tt11046300
# 84                      Mukkabaaz   tt7180544
# 143                       Tumbbad   tt8239946
# 146                     Andhadhun   tt8108198
# 192      Sachin: A Billion Dreams   tt4640206
# 279            Nil Battey Sannata   tt5005684
# 325              Pink (2016 film)   tt5571734
# 354                 Dangal (film)   tt5074352
# 418                        Masaan   tt4635372
# 426          Drishyam (2015 film)   tt4430212
# 436                 Talvar (film)   tt4934950
# ...

# %%
mov[(mov['imdb_rating']>8)&(mov['imdb_votes']>1000)].shape[0]
# Out:
# 53

# %% [markdown]
# # Action movies with rating higher than 7.5

# %%
mask1 = mov['genres'].str.split('|').apply(lambda x:'Action' in x)
mask2 =(mov['imdb_rating']>7.5)
mov[mask2& mask1].shape[0]
# Out:
# 33
