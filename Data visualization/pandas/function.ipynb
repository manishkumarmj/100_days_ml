# %%
# apply
# astype
# between
# clip
# copy
# count
# describe
# drop_duplicates
# dropna
# dtype
# fillna
# head
# index
# integer indexing
# is_unique
# isnull
# isin
# max
# mean
# median
# mode
# read_csv
# size
# slicing
# set_index
# sort_index
# sort_values
# std
# sum
# tail
# type conversion
# value_counts
# values
# var
