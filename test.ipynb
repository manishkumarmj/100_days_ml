# %%
run= ['Data', 'science', 'mentorship', 'program']

# %%
for i in run:
    run.append(i)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 for i in run:
# ----> 2     run.append(i)
#
# KeyboardInterrupt:
